# %% [markdown]
# # 获取 GitHub 项目进展
#
# 以下代码主要由 GPT-4 生成，演示 `GitHubClient` 模块的版本演进。
#
#
# ## 使用 GitHub REST API 获取项目信息
#
# GitHub REST API 为开发者提供了便捷获取 GitHub 项目的丰富 API。
#
# ![Github Docs](images/github_docs.png)
#
# 例如，获取项目 issues 列表，GitHub 提供了 `"List repository issues"` API。
#
#
# ## GitHub Token 配置
#
# 使用 `GitHubClient` 模块调用 GitHub REST API 需要配置 [GitHub Fine-grained personal access token](https://github.com/settings/tokens?type=beta)。
#
# - **配置文件**：正式启动 GitHubSentinel 项目，可以替换 `config.json` 中 `github_token` 值。
# - **Jupyter测试**：在使用构造函数实例化 GitHubClient 类，以参数形式传入。
#
# 下面以 https://github.com/langchain-ai/langchain 项目为例，演示 GitHubClient 使用方法

# %% [markdown]
# ## [v0.2] GitHubClient Class

# %%
# src/github_client.py

import requests  # 导入requests库用于发起HTTP请求
import datetime  # 导入datetime库处理日期和时间

class GitHubClient:
    def __init__(self, token):
        self.token = token  # GitHub的访问令牌
        # 初始化请求头部，这里主要是为了使用GitHub的API进行身份验证
        self.headers = {'Authorization': f'token {self.token}'}

    def fetch_updates(self, repos):
        # 为给定的仓库列表获取更新，包括提交、问题和拉取请求
        updates = {}
        for repo in repos:
            # 遍历每个仓库并获取相关信息
            updates[repo] = {
                'commits': self.fetch_commits(repo),  # 获取提交记录
                'issues': self.fetch_issues(repo),   # 获取问题
                'pull_requests': self.fetch_pull_requests(repo)  # 获取拉取请求
            }
        return updates

    def fetch_commits(self, repo):
        # 构建获取提交记录的API URL
        url = f'https://api.github.com/repos/{repo}/commits'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()  # 检查请求是否成功，如果出错则抛出异常
        return response.json()  # 返回解析JSON格式的数据

    def fetch_issues(self, repo):
        # 构建获取问题(issue)的API URL
        url = f'https://api.github.com/repos/{repo}/issues'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()  # 确保响应没有HTTP错误
        return response.json()  # 返回JSON数据

    def fetch_pull_requests(self, repo):
        # 构建获取拉取请求(pull requests)的API URL
        url = f'https://api.github.com/repos/{repo}/pulls'
        response = requests.get(url, headers=self.headers)
        response.raise_for_status()
        return response.json()  # 返回JSON格式的拉取请求数据

    def export_daily_progress(self, repo):
        # 导出指定仓库的每日进度，包括问题和拉取请求
        date_str = datetime.datetime.now().strftime('%Y-%m-%d')  # 获取当前日期字符串
        issues = self.fetch_issues(repo)  # 获取当天的问题
        pull_requests = self.fetch_pull_requests(repo)  # 获取当天的拉取请求
        filename = f"{repo.replace('/', '_')}_{date_str}.md"  # 根据仓库名和日期生成文件名

        # 打开文件进行写入
        with open(filename, 'w') as f:
            f.write(f"# {repo} Daily Progress - {date_str}\n\n")  # 写入标题
            f.write("## Issues\n")
            for issue in issues:
                f.write(f"- {issue['title']} #{issue['number']}\n")  # 列出每个问题
            f.write("\n## Pull Requests\n")
            for pr in pull_requests:
                f.write(f"- {pr['title']} #{pr['number']}\n")  # 列出每个拉取请求

        print(f"Exported daily progress to {filename}")  # 打印导出信息

        return filename

# %% [markdown]
# ### 实例化 GitHubClient
#
# 从环境变量中获取 `GITHUB_TOKEN`，依次获取 Commits, Issues 和 Pull Requests。

# %%
import os

github_client = GitHubClient(token="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")

# %% [markdown]
# ### List Issues API
#
# API完整文档说明见：https://docs.github.com/en/rest/issues/issues?apiVersion=2022-11-28#list-repository-issues
#
# **请求样例**：`GET /repos/{owner}/{repo}/issues`;
#
# **返回样例**：
#
# ```json
# [
#   {
#     "id": 1,
#     "node_id": "MDU6SXNzdWUx",
#     "url": "https://api.github.com/repos/octocat/Hello-World/issues/1347",
#     "repository_url": "https://api.github.com/repos/octocat/Hello-World",
#     "labels_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/labels{/name}",
#     "comments_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/comments",
#     "events_url": "https://api.github.com/repos/octocat/Hello-World/issues/1347/events",
#     "html_url": "https://github.com/octocat/Hello-World/issues/1347",
#     "number": 1347,
#     "state": "open",
#     "title": "Found a bug",
#     "body": "I'm having a problem with this.",
#     "user": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "labels": [
#       {
#         "id": 208045946,
#         "node_id": "MDU6TGFiZWwyMDgwNDU5NDY=",
#         "url": "https://api.github.com/repos/octocat/Hello-World/labels/bug",
#         "name": "bug",
#         "description": "Something isn't working",
#         "color": "f29513",
#         "default": true
#       }
#     ],
#     "assignee": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "assignees": [
#       {
#         "login": "octocat",
#         "id": 1,
#         "node_id": "MDQ6VXNlcjE=",
#         "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/octocat",
#         "html_url": "https://github.com/octocat",
#         "followers_url": "https://api.github.com/users/octocat/followers",
#         "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#         "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#         "organizations_url": "https://api.github.com/users/octocat/orgs",
#         "repos_url": "https://api.github.com/users/octocat/repos",
#         "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/octocat/received_events",
#         "type": "User",
#         "site_admin": false
#       }
#     ],
#     "milestone": {
#       "url": "https://api.github.com/repos/octocat/Hello-World/milestones/1",
#       "html_url": "https://github.com/octocat/Hello-World/milestones/v1.0",
#       "labels_url": "https://api.github.com/repos/octocat/Hello-World/milestones/1/labels",
#       "id": 1002604,
#       "node_id": "MDk6TWlsZXN0b25lMTAwMjYwNA==",
#       "number": 1,
#       "state": "open",
#       "title": "v1.0",
#       "description": "Tracking milestone for version 1.0",
#       "creator": {
#         "login": "octocat",
#         "id": 1,
#         "node_id": "MDQ6VXNlcjE=",
#         "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#         "gravatar_id": "",
#         "url": "https://api.github.com/users/octocat",
#         "html_url": "https://github.com/octocat",
#         "followers_url": "https://api.github.com/users/octocat/followers",
#         "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#         "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#         "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#         "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#         "organizations_url": "https://api.github.com/users/octocat/orgs",
#         "repos_url": "https://api.github.com/users/octocat/repos",
#         "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#         "received_events_url": "https://api.github.com/users/octocat/received_events",
#         "type": "User",
#         "site_admin": false
#       },
#       "open_issues": 4,
#       "closed_issues": 8,
#       "created_at": "2011-04-10T20:09:31Z",
#       "updated_at": "2014-03-03T18:58:10Z",
#       "closed_at": "2013-02-12T13:22:01Z",
#       "due_on": "2012-10-09T23:39:01Z"
#     },
#     "locked": true,
#     "active_lock_reason": "too heated",
#     "comments": 0,
#     "pull_request": {
#       "url": "https://api.github.com/repos/octocat/Hello-World/pulls/1347",
#       "html_url": "https://github.com/octocat/Hello-World/pull/1347",
#       "diff_url": "https://github.com/octocat/Hello-World/pull/1347.diff",
#       "patch_url": "https://github.com/octocat/Hello-World/pull/1347.patch"
#     },
#     "closed_at": null,
#     "created_at": "2011-04-22T13:33:48Z",
#     "updated_at": "2011-04-22T13:33:48Z",
#     "closed_by": {
#       "login": "octocat",
#       "id": 1,
#       "node_id": "MDQ6VXNlcjE=",
#       "avatar_url": "https://github.com/images/error/octocat_happy.gif",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/octocat",
#       "html_url": "https://github.com/octocat",
#       "followers_url": "https://api.github.com/users/octocat/followers",
#       "following_url": "https://api.github.com/users/octocat/following{/other_user}",
#       "gists_url": "https://api.github.com/users/octocat/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/octocat/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/octocat/subscriptions",
#       "organizations_url": "https://api.github.com/users/octocat/orgs",
#       "repos_url": "https://api.github.com/users/octocat/repos",
#       "events_url": "https://api.github.com/users/octocat/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/octocat/received_events",
#       "type": "User",
#       "site_admin": false
#     },
#     "author_association": "COLLABORATOR",
#     "state_reason": "completed"
#   }
# ]
# ```

# %%
repo = "langchain-ai/langchain"

# %%
issues = github_client.fetch_issues(repo)

# %% [markdown]
# ### GitHubClient fetch 方法 repo 参数格式要求
#
# 从 GitHub 获取项目进展，需要访问形如 `https://api.github.com/repos/{repo}/issues`(以issues为例）的 URL。因此，repo 必须符合 GitHub Repo 标准命名，如下所示:
#
# ```json
# [
#     "langchain-ai/langchain",
#     "DjangoPeng/openai-quickstart",
#     "ollama/ollama"
# ]
# ```
#
# **GitHubSentinel 项目订阅管理配置文件为 `subscriptions.json`。**

# %%
issues
# Out:
# [{'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27330',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27330/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27330/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27330/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/27330',
#   'id': 2584904959,
#   'node_id': 'PR_kwDOIPDwls5-fLbd',
#   'number': 27330,
#   'title': 'community: Add support for clob datatype in oracle database',
#   'user': {'login': 'xsai9101',
#    'id': 158216624,
#    'node_id': 'U_kgDOCW4xsA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/158216624?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xsai9101',
#    'html_url': 'https://github.com/xsai9101',
#    'followers_url': 'https://api.github.com/users/xsai9101/followers',
#    'following_url': 'https://api.github.com/users/xsai9101/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/xsai9101/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/xsai9101/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/xsai9101/subscriptions',
#    'organizations_url': 'https://api.github.com/users/xsai9101/orgs',
#    'repos_url': 'https://api.github.com/users/xsai9101/repos',
#    'events_url': 'https://api.github.com/users/xsai9101/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/xsai9101/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5541144676,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkcoZA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20doc%20loader',
#     'name': 'Ɑ: doc loader',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to document loader module (not documentation)'},
#    {'id': 6232714119,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rhw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:M',
#     'name': 'size:M',
#     'color': 'FEF2C0',
#     'default': False,
#     'description': 'This PR changes 30-99 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-10-14T06:22:50Z',
#   'updated_at': '2024-10-14T06:23:21Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27330',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/27330',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/27330.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/27330.patch',
#    'merged_at': None},
#   'body': '**Description**:\r\nThis PR add support of clob/blob data type for oracle document loader, clob/blob can only be read by oracledb package when connection is open, so reformat code to process data before connection closes.\r\n\r\n**Dependencies**:\r\noracledb package same as before. pip install oracledb\r\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27330/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27330/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27329',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27329/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27329/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27329/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/27329',
#   'id': 2584897944,
#   'node_id': 'PR_kwDOIPDwls5-fJ1L',
#   'number': 27329,
#   'title': 'LangChain Community: VectorStores: Azure Cosmos DB Mongo vCore with DiskANN',
#   'user': {'login': 'fatmelon',
#    'id': 9691826,
#    'node_id': 'MDQ6VXNlcjk2OTE4MjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9691826?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fatmelon',
#    'html_url': 'https://github.com/fatmelon',
#    'followers_url': 'https://api.github.com/users/fatmelon/followers',
#    'following_url': 'https://api.github.com/users/fatmelon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fatmelon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fatmelon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fatmelon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fatmelon/orgs',
#    'repos_url': 'https://api.github.com/users/fatmelon/repos',
#    'events_url': 'https://api.github.com/users/fatmelon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fatmelon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5541432778,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkuNyg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20vector%20store',
#     'name': 'Ɑ: vector store',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to vector store module'},
#    {'id': 6232714130,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rkg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XL',
#     'name': 'size:XL',
#     'color': 'E99695',
#     'default': False,
#     'description': 'This PR changes 500-999 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-10-14T06:19:40Z',
#   'updated_at': '2024-10-14T06:44:58Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27329',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/27329',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/27329.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/27329.patch',
#    'merged_at': None},
#   'body': '# Description\r\nAdd a new vector index type `diskann` to Azure Cosmos DB Mongo vCore vector store. Paper of DiskANN can be found here [DiskANN: Fast Accurate Billion-point Nearest Neighbor Search on a Single Node](https://proceedings.neurips.cc/paper_files/paper/2019/file/09853c7fb1d3f8ee67a61b6bf4a7f8e6-Paper.pdf).\r\n\r\n## Sample Usage\r\n```python\r\nfrom pymongo import MongoClient\r\n\r\n# INDEX_NAME = "izzy-test-index-2"\r\n# NAMESPACE = "izzy_test_db.izzy_test_collection"\r\n# DB_NAME, COLLECTION_NAME = NAMESPACE.split(".")\r\n\r\nclient: MongoClient = MongoClient(CONNECTION_STRING)\r\ncollection = client[DB_NAME][COLLECTION_NAME]\r\n\r\nmodel_deployment = os.getenv(\r\n    "OPENAI_EMBEDDINGS_DEPLOYMENT", "smart-agent-embedding-ada"\r\n)\r\nmodel_name = os.getenv("OPENAI_EMBEDDINGS_MODEL_NAME", "text-embedding-ada-002")\r\n\r\nvectorstore = AzureCosmosDBVectorSearch.from_documents(\r\n    docs,\r\n    openai_embeddings,\r\n    collection=collection,\r\n    index_name=INDEX_NAME,\r\n)\r\n\r\n# Read more about these variables in detail here. https://learn.microsoft.com/en-us/azure/cosmos-db/mongodb/vcore/vector-search\r\nmaxDegree = 40\r\ndimensions = 1536\r\nsimilarity_algorithm = CosmosDBSimilarityType.COS\r\nkind = CosmosDBVectorSearchType.VECTOR_HNSW\r\nlBuild = 20\r\n\r\nvectorstore.create_index(\r\n            dimensions=dimensions,\r\n            similarity=similarity_algorithm,\r\n            kind=kind ,\r\n            max_degree=maxDegree,\r\n            l_build=lBuild,\r\n        )\r\n```\r\n\r\n## Dependencies\r\nNo additional dependencies were added',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27329/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27329/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27327',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27327/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27327/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27327/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/27327',
#   'id': 2584676304,
#   'node_id': 'PR_kwDOIPDwls5-edUw',
#   'number': 27327,
#   'title': 'community: fixes json loader not getting texts with json standard',
#   'user': {'login': 'TonyBotongChu',
#    'id': 19709245,
#    'node_id': 'MDQ6VXNlcjE5NzA5MjQ1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19709245?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TonyBotongChu',
#    'html_url': 'https://github.com/TonyBotongChu',
#    'followers_url': 'https://api.github.com/users/TonyBotongChu/followers',
#    'following_url': 'https://api.github.com/users/TonyBotongChu/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/TonyBotongChu/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/TonyBotongChu/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/TonyBotongChu/subscriptions',
#    'organizations_url': 'https://api.github.com/users/TonyBotongChu/orgs',
#    'repos_url': 'https://api.github.com/users/TonyBotongChu/repos',
#    'events_url': 'https://api.github.com/users/TonyBotongChu/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/TonyBotongChu/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5541144676,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkcoZA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20doc%20loader',
#     'name': 'Ɑ: doc loader',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to document loader module (not documentation)'},
#    {'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-10-14T04:05:35Z',
#   'updated_at': '2024-10-14T04:05:56Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27327',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/27327',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/27327.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/27327.patch',
#    'merged_at': None},
#   'body': 'This PR fixes JSONLoader._get_text not converting objects to json string correctly.\r\nIf an object is serializable and is not a dict, JSONLoader will use python built-in str() method to convert it to string. This may cause object converted to strings not following json standard. For example, a list will be converted to string with single quotes, and if json.loads try to load this string, it will cause error.\r\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27327/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27327/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27326',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27326/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27326/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27326/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/27326',
#   'id': 2584515720,
#   'node_id': 'PR_kwDOIPDwls5-d-UA',
#   'number': 27326,
#   'title': 'Add gpt-researcher tool implementation',
#   'user': {'login': 'Makesh-Srinivasan',
#    'id': 66047630,
#    'node_id': 'MDQ6VXNlcjY2MDQ3NjMw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66047630?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Makesh-Srinivasan',
#    'html_url': 'https://github.com/Makesh-Srinivasan',
#    'followers_url': 'https://api.github.com/users/Makesh-Srinivasan/followers',
#    'following_url': 'https://api.github.com/users/Makesh-Srinivasan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Makesh-Srinivasan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Makesh-Srinivasan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Makesh-Srinivasan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Makesh-Srinivasan/orgs',
#    'repos_url': 'https://api.github.com/users/Makesh-Srinivasan/repos',
#    'events_url': 'https://api.github.com/users/Makesh-Srinivasan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Makesh-Srinivasan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 6232714126,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rjg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:L',
#     'name': 'size:L',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'This PR changes 100-499 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-10-14T01:46:32Z',
#   'updated_at': '2024-10-14T01:57:04Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27326',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/27326',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/27326.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/27326.patch',
#    'merged_at': None},
#   'body': 'Thank you for contributing to LangChain!\r\n\r\n- [ ] **PR title**: "community: add GPT-Researcher tool"\r\n\r\n\r\n- [ ] **PR message**: ***Delete this entire checklist*** and replace with\r\n    - **Description:** GPTResearcher – an LLM-powered autonomous agent that dives deep into **web, local, or hybrid sources** to deliver **comprehensive research on any topic**. Now available as a **LangChain Tool**, seamlessly integrate it into **ANY** agent ecosystem and elevate your AI workflows.\r\n    - **Issue:** N/A\r\n    - **Dependencies:** gpt-researcher (https://pypi.org/project/gpt-researcher/)\r\n    - **Twitter handle:** I don\'t have twitter but a mention of my LinkedIn would help - https://www.linkedin.com/in/makesh-srinivasan/\r\n\r\n\r\n- [ ] **Add tests and docs**: If you\'re adding a new integration, please include\r\n  1. a test for the integration, preferably unit tests that do not rely on network access,\r\n  2. an example notebook showing its use. It lives in `docs/docs/integrations` directory.\r\n\r\n\r\n- [ ] **Lint and test**: Run `make format`, `make lint` and `make test` from the root of the package(s) you\'ve modified. See contribution guidelines for more: https://python.langchain.com/docs/contributing/\r\n\r\nAdditional guidelines:\r\n- Make sure optional dependencies are imported within a function.\r\n- Please do not add dependencies to pyproject.toml files (even optional ones) unless they are required for unit tests.\r\n- Most PRs should not touch more than one package.\r\n- Changes should be backwards compatible.\r\n- If you are adding something to community, do not re-import it in langchain.\r\n\r\nIf no one reviews your PR within a few days, please @-mention one of baskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.\r\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27326/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27326/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27325',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27325/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27325/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27325/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/27325',
#   'id': 2584447759,
#   'node_id': 'I_kwDOIPDwls6aC4sP',
#   'number': 27325,
#   'title': 'langchain_openai reports error `role Input should be a valid string` when connecting to specific LLM API',
#   'user': {'login': 'Moskize91',
#    'id': 14900772,
#    'node_id': 'MDQ6VXNlcjE0OTAwNzcy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14900772?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Moskize91',
#    'html_url': 'https://github.com/Moskize91',
#    'followers_url': 'https://api.github.com/users/Moskize91/followers',
#    'following_url': 'https://api.github.com/users/Moskize91/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Moskize91/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Moskize91/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Moskize91/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Moskize91/orgs',
#    'repos_url': 'https://api.github.com/users/Moskize91/repos',
#    'events_url': 'https://api.github.com/users/Moskize91/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Moskize91/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-10-14T00:36:27Z',
#   'updated_at': '2024-10-14T00:53:16Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Checked other resources\r\n\r\n- [X] I added a very descriptive title to this issue.\r\n- [X] I searched the LangChain documentation with the integrated search.\r\n- [X] I used the GitHub search to find a similar question and didn\'t find it.\r\n- [X] I am sure that this is a bug in LangChain rather than my code.\r\n- [X] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\r\n\r\n### Example Code\r\n\r\n```python\r\nfrom langchain_openai import ChatOpenAI\r\n\r\napi_key = "XXXXXXXX"\r\nmodel_name="gpt-3.5-turbo"\r\nbase_url = "https://XXXXXX" # specific LLM vendor\r\nllm = ChatOpenAI(\r\n    api_key=api_key,\r\n    base_url=base_url\r\n    model=model_name,\r\n)\r\nllm.invoke("hello world")\r\n```\r\n\r\n### Error Message and Stack Trace (if applicable)\r\n```\r\nTraceback (most recent call last):\r\n  File "/Users/taozeyu/codes/github.com/moksize91/llm-inception/server/llm/node.py", line 320, in _invoke\r\n    resp_content = chain.invoke(\r\n                   ^^^^^^^^^^^^^\r\n  File "/Users/taozeyu/codes/github.com/moksize91/llm-inception/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 3022, in invoke\r\n    input = context.run(step.invoke, input, config, **kwargs)\r\n            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\r\n  File "/Users/taozeyu/codes/github.com/moksize91/llm-inception/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py", line 286, in invoke\r\n    self.generate_prompt(\r\n  File "/Users/taozeyu/codes/github.com/moksize91/llm-inception/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py", line 786, in generate_prompt\r\n    return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)\r\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\r\n  File "/Users/taozeyu/codes/github.com/moksize91/llm-inception/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py", line 643, in generate\r\n    raise e\r\n  File "/Users/taozeyu/codes/github.com/moksize91/llm-inception/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py", line 633, in generate\r\n    self._generate_with_cache(\r\n  File "/Users/taozeyu/codes/github.com/moksize91/llm-inception/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py", line 851, in _generate_with_cache\r\n    result = self._generate(\r\n             ^^^^^^^^^^^^^^^\r\n  File "/Users/taozeyu/codes/github.com/moksize91/llm-inception/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py", line 685, in _generate\r\n    return self._create_chat_result(response, generation_info)\r\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\r\n  File "/Users/taozeyu/codes/github.com/moksize91/llm-inception/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py", line 722, in _create_chat_result\r\n    message = _convert_dict_to_message(res["message"])\r\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\r\n  File "/Users/taozeyu/codes/github.com/moksize91/llm-inception/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py", line 159, in _convert_dict_to_message\r\n    return ChatMessage(content=_dict.get("content", ""), role=role, id=id_)  # type: ignore[arg-type]\r\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\r\n  File "/Users/taozeyu/codes/github.com/moksize91/llm-inception/.venv/lib/python3.12/site-packages/langchain_core/messages/base.py", line 76, in __init__\r\n    super().__init__(content=content, **kwargs)\r\n  File "/Users/taozeyu/codes/github.com/moksize91/llm-inception/.venv/lib/python3.12/site-packages/langchain_core/load/serializable.py", line 111, in __init__\r\n    super().__init__(*args, **kwargs)\r\n  File "/Users/taozeyu/codes/github.com/moksize91/llm-inception/.venv/lib/python3.12/s ...
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27325/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27325/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27324',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27324/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27324/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27324/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/27324',
#   'id': 2584383717,
#   'node_id': 'PR_kwDOIPDwls5-djN3',
#   'number': 27324,
#   'title': 'Community: OpenSky Network Document Loader',
#   'user': {'login': 'AndrewEffendi',
#    'id': 84085709,
#    'node_id': 'MDQ6VXNlcjg0MDg1NzA5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84085709?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AndrewEffendi',
#    'html_url': 'https://github.com/AndrewEffendi',
#    'followers_url': 'https://api.github.com/users/AndrewEffendi/followers',
#    'following_url': 'https://api.github.com/users/AndrewEffendi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/AndrewEffendi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/AndrewEffendi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/AndrewEffendi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/AndrewEffendi/orgs',
#    'repos_url': 'https://api.github.com/users/AndrewEffendi/repos',
#    'events_url': 'https://api.github.com/users/AndrewEffendi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/AndrewEffendi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5541144676,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkcoZA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20doc%20loader',
#     'name': 'Ɑ: doc loader',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to document loader module (not documentation)'},
#    {'id': 6232714126,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rjg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:L',
#     'name': 'size:L',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'This PR changes 100-499 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-10-13T23:38:15Z',
#   'updated_at': '2024-10-14T00:57:59Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27324',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/27324',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/27324.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/27324.patch',
#    'merged_at': None},
#   'body': '# Description\r\nAs proposed in our earlier discussion [27193](https://github.com/langchain-ai/langchain/discussions/27193) we have introduced OpenSky Network Document Loader that utilize OpenSky Network API found at https://openskynetwork.github.io/opensky-api/rest.html to load Air Traffic Data\r\n\r\n## Sample Usage\r\n```python\r\nimport time\r\nfrom langchain_community.document_loaders import OpenSkyLoader\r\nfrom langchain_community.utilities import OpenSkyAPIWrapper\r\n\r\n# Example: Get the current Unix time\r\ncurrent_time = int(time.time())\r\n# Get the Unix time for one hour ago\r\none_hour_ago = current_time - 6000\r\n\r\n# Load flights by time interval\r\ninterval_loader = OpenSkyLoader(\r\n    api_wrapper=OpenSkyAPIWrapper(),\r\n    mode="by_interval",\r\n    params={"begin": one_hour_ago, "end": current_time},\r\n)\r\ninterval_data = list(interval_loader.lazy_load())\r\nprint("Flights in the Last Hour:")\r\nfor doc in interval_data:\r\n    print(doc.page_content, doc.metadata)\r\n```\r\n\r\n## Sample Output\r\n```\r\n{\'ICAO 24 Address\': \'ace463\', \'Callsign\': \'N93M\', \'Country\': \'United States\', \'Last Position Update\': \'2024-10-13T19:29:25\', \'Last Contact\': \'2024-10-13T19:29:25\', \'Longitude\': -123.915, \'Latitude\': 48.2887, \'Barometric Altitude\': 9608.82, \'On Ground\': False, \'Velocity\': 242.74, \'True Track\': 307.77, \'Vertical Rate\': 8.13, \'Sensors\': None, \'Geometric Altitude\': 9982.2, \'Squawk\': \'1570\', \'Special Purpose Indicator\': False, \'Position Source\': \'ADS-B\', \'Category\': None} {\'mode\': \'all_states\', \'queried_at\': datetime.datetime(2024, 10, 13, 19, 29, 31, 320218)}\r\n{\'ICAO 24 Address\': \'407f7c\', \'Callsign\': \'EXS14NE\', \'Country\': \'United Kingdom\', \'Last Position Update\': \'2024-10-13T19:29:25\', \'Last Contact\': \'2024-10-13T19:29:25\', \'Longitude\': -2.6977, \'Latitude\': 44.3167, \'Barometric Altitude\': 10972.8, \'On Ground\': False, \'Velocity\': 232.25, \'True Track\': 8.92, \'Vertical Rate\': 0, \'Sensors\': None, \'Geometric Altitude\': 11437.62, \'Squawk\': \'7476\', \'Special Purpose Indicator\': False, \'Position Source\': \'ADS-B\', \'Category\': None} {\'mode\': \'all_states\', \'queried_at\': datetime.datetime(2024, 10, 13, 19, 29, 31, 320218)}\r\n{\'ICAO 24 Address\': \'407f7a\', \'Callsign\': \'EZY74QD\', \'Country\': \'United Kingdom\', \'Last Position Update\': \'2024-10-13T19:29:25\', \'Last Contact\': \'2024-10-13T19:29:25\', \'Longitude\': 5.0596, \'Latitude\': 48.4958, \'Barometric Altitude\': 10972.8, \'On Ground\': False, \'Velocity\': 222.37, \'True Track\': 310.03, \'Vertical Rate\': 0, \'Sensors\': None, \'Geometric Altitude\': 11384.28, \'Squawk\': \'2746\', \'Special Purpose Indicator\': False, \'Position Source\': \'ADS-B\', \'Category\': None} {\'mode\': \'all_states\', \'queried_at\': datetime.datetime(2024, 10, 13, 19, 29, 31, 320218)}\r\n\r\n```\r\n## Dependencies\r\nNo additional dependencies were added',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27324/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27324/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27323',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27323/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27323/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27323/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/27323',
#   'id': 2584271324,
#   'node_id': 'PR_kwDOIPDwls5-dTKe',
#   'number': 27323,
#   'title': 'community: Memcached LLM Cache Integration',
#   'user': {'login': 'prokopchukdim',
#    'id': 87666671,
#    'node_id': 'MDQ6VXNlcjg3NjY2Njcx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/87666671?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/prokopchukdim',
#    'html_url': 'https://github.com/prokopchukdim',
#    'followers_url': 'https://api.github.com/users/prokopchukdim/followers',
#    'following_url': 'https://api.github.com/users/prokopchukdim/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/prokopchukdim/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/prokopchukdim/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/prokopchukdim/subscriptions',
#    'organizations_url': 'https://api.github.com/users/prokopchukdim/orgs',
#    'repos_url': 'https://api.github.com/users/prokopchukdim/repos',
#    'events_url': 'https://api.github.com/users/prokopchukdim/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/prokopchukdim/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 6232714126,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rjg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:L',
#     'name': 'size:L',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'This PR changes 100-499 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-10-13T21:00:13Z',
#   'updated_at': '2024-10-14T01:17:58Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27323',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/27323',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/27323.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/27323.patch',
#    'merged_at': None},
#   'body': '## Description\r\nThis PR adds support for Memcached as a usable LLM model cache by adding the  ```MemcachedCache``` implementation relying on the [pymemcache](https://github.com/pinterest/pymemcache) client.\r\n\r\nUnit test-wise, the new integration is generally covered under existing import testing. All new functionality depends on pymemcache if instantiated and used, so to comply with the other cache implementations the PR also adds optional integration tests for ```MemcachedCache```.\r\n\r\nSince this is a new integration, documentation is added for Memcached as an integration and as an LLM Cache.\r\n\r\n## Issue\r\nThis PR closes #27275 which was originally raised as a discussion in #27035\r\n\r\n## Dependencies\r\nThere are no new required dependencies for langchain, but [pymemcache](https://github.com/pinterest/pymemcache) is required to instantiate the new ```MemcachedCache```.\r\n\r\n## Example Usage\r\n```python3\r\nfrom langchain.globals import set_llm_cache\r\nfrom langchain_openai import OpenAI\r\n\r\nfrom langchain_community.cache import MemcachedCache\r\nfrom pymemcache.client.base import Client\r\n\r\nllm = OpenAI(model="gpt-3.5-turbo-instruct", n=2, best_of=2)\r\nset_llm_cache(MemcachedCache(Client(\'localhost\')))\r\n\r\n# The first time, it is not yet in cache, so it should take longer\r\nllm.invoke("Which city is the most crowded city in the USA?")\r\n\r\n# The second time it is, so it goes faster\r\nllm.invoke("Which city is the most crowded city in the USA?")\r\n```\r\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27323/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27323/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27322',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27322/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27322/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27322/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/27322',
#   'id': 2584236894,
#   'node_id': 'PR_kwDOIPDwls5-dPDk',
#   'number': 27322,
#   'title': 'community: Resolve Pydantic AttributeError in document_loaders/youtube.py',
#   'user': {'login': 'TupleType',
#    'id': 88270351,
#    'node_id': 'MDQ6VXNlcjg4MjcwMzUx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/88270351?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TupleType',
#    'html_url': 'https://github.com/TupleType',
#    'followers_url': 'https://api.github.com/users/TupleType/followers',
#    'following_url': 'https://api.github.com/users/TupleType/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/TupleType/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/TupleType/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/TupleType/subscriptions',
#    'organizations_url': 'https://api.github.com/users/TupleType/orgs',
#    'repos_url': 'https://api.github.com/users/TupleType/repos',
#    'events_url': 'https://api.github.com/users/TupleType/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/TupleType/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 6232714108,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rfA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:S',
#     'name': 'size:S',
#     'color': 'BFDADC',
#     'default': False,
#     'description': 'This PR changes 10-29 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-10-13T20:07:38Z',
#   'updated_at': '2024-10-13T20:08:00Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27322',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/27322',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/27322.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/27322.patch',
#    'merged_at': None},
#   'body': 'This error is thrown when upgrading to the latest langchain version:\r\n```\r\nif not values.get("credentials_path") and not values.get(\r\n           ^^^^^^^^^^\r\nAttributeError: \'pydantic_core._pydantic_core.ArgsKwargs\' object has no attribute \'get\'\r\n```\r\nI tested the fix locally',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27322/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27322/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27317',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27317/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27317/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27317/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/27317',
#   'id': 2584034218,
#   'node_id': 'PR_kwDOIPDwls5-c18C',
#   'number': 27317,
#   'title': 'docs: Maybe there is a missing closing bracket.',
#   'user': {'login': 'YangZhaoo',
#    'id': 41366656,
#    'node_id': 'MDQ6VXNlcjQxMzY2NjU2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41366656?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/YangZhaoo',
#    'html_url': 'https://github.com/YangZhaoo',
#    'followers_url': 'https://api.github.com/users/YangZhaoo/followers',
#    'following_url': 'https://api.github.com/users/YangZhaoo/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/YangZhaoo/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/YangZhaoo/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/YangZhaoo/subscriptions',
#    'organizations_url': 'https://api.github.com/users/YangZhaoo/orgs',
#    'repos_url': 'https://api.github.com/users/YangZhaoo/repos',
#    'events_url': 'https://api.github.com/users/YangZhaoo/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/YangZhaoo/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700883,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpid0w',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:nit',
#     'name': '🤖:nit',
#     'color': 'C5DEF5',
#     'default': False,
#     'description': 'Small modifications/deletions, fixes, deps or improvements to existing code or docs'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 7110712909,
#     'node_id': 'LA_kwDOIPDwls8AAAABp9TeTQ',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/langchain',
#     'name': 'langchain',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Related to the langchain package'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2024-10-13T14:56:51Z',
#   'updated_at': '2024-10-13T15:15:11Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27317',
#    'html_url': 'https://github.com/langchain-ai/langchain/pull/27317',
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/27317.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/27317.patch',
#    'merged_at': None},
#   'body': 'Thank you for contributing to LangChain!\r\n\r\n- [x] **PR title**: "package: description"\r\n  - Where "package" is whichever of langchain, community, core, etc. is being modified. Use "docs: ..." for purely docs changes, "templates: ..." for template changes, "infra: ..." for CI changes.\r\n  - Example: "community: add foobar LLM"\r\n\r\n\r\n- [ ] **PR message**: ***Delete this entire checklist*** and replace with\r\n    - **Description:** a description of the change\r\n    - **Issue:** the issue # it fixes, if applicable\r\n    - **Dependencies:** any dependencies required for this change\r\n    - **Twitter handle:** if your PR gets announced, and you\'d like a mention, we\'ll gladly shout you out!\r\n\r\n\r\n- [ ] **Add tests and docs**: If you\'re adding a new integration, please include\r\n  1. a test for the integration, preferably unit tests that do not rely on network access,\r\n  2. an example notebook showing its use. It lives in `docs/docs/integrations` directory.\r\n\r\n\r\n- [ ] **Lint and test**: Run `make format`, `make lint` and `make test` from the root of the package(s) you\'ve modified. See contribution guidelines for more: https://python.langchain.com/docs/contributing/\r\n\r\nAdditional guidelines:\r\n- Make sure optional dependencies are imported within a function.\r\n- Please do not add dependencies to pyproject.toml files (even optional ones) unless they are required for unit tests.\r\n- Most PRs should not touch more than one package.\r\n- Changes should be backwards compatible.\r\n- If you are adding something to community, do not re-import it in langchain.\r\n\r\nIf no one reviews your PR within a few days, please @-mention one of baskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.\r\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27317/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27317/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27316',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27316/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27316/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27316/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/27316',
#   'id': 2584021568,
#   'node_id': 'PR_kwDOIPDwls5-c0te',
#   'number': 27316,
#   'title': '[community][fix] Compatibility support to bump up wikibase-rest-api-client version',
#   'user': {'login': 'Rock2z',
#    'id': 44712825,
#    'node_id': 'MDQ6VXNlcjQ0NzEyODI1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44712825?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Rock2z',
#    'html_url': 'https://github.com/Rock2z',
#    'followers_url': 'https://api.github.com/users/Rock2z/followers',
#    'following_url': 'https://api.github.com/users/Rock2z/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Rock2z/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Rock2z/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Rock2z/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Rock2z/orgs',
#    'repos_url': 'https://api.github.com/users/Rock2z/repos',
#    'events_url': 'https://api.github.com/users/Rock2z/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Rock2z/received_events',
#    'type': 'User',
#    'site_admin': False},
# ...
#    'diff_url': 'https://github.com/langchain-ai/langchain/pull/27271.diff',
#    'patch_url': 'https://github.com/langchain-ai/langchain/pull/27271.patch',
#    'merged_at': None},
#   'body': 'This pull request introduces [OceanBase](https://github.com/oceanbase/oceanbase) as an alternative vector store.  The vector storage capability of `OceanBase` is still being enhanced, and currently has the following limitation:\r\n\r\n- Cosine vector distance function is not yet supported for vector index. Currently only inner product distance and Euclidean distance are supported, and Euclidean distance is used by default. **This issue will lead to two requirements: 1) When initializing OceanBase, `normalize=True` needs to be set to normalize the Euclidean distance. 2) When using `similarity_search_with_relevance_scores`, `score_threshold` may need to be set to a smaller value than when using cosine distance.**\r\n\r\nWe will support cosine distance soon. \r\n\r\nSimple example of using `OceanBase` as vector store:\r\n\r\n```python\r\nfrom langchain_community.vectorstores.oceanbase import OceanBase\r\nfrom tests.integration_tests.vectorstores.fake_embeddings import FakeEmbeddings\r\n\r\ntexts = ["foo", "bar", "baz"]\r\nmetadatas = [{"page": str(i)} for i in range(len(texts))]\r\ndocsearch = OceanBase.from_texts(\r\n    texts=texts,\r\n    embedding=FakeEmbeddings(),\r\n    metadatas=metadatas,\r\n    connection_args=CONNECTION_ARGS,\r\n    drop_old=True,\r\n    normalize=True,\r\n)\r\noutput = docsearch.similarity_search("foo", k=1)\r\n```',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27271/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27271/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27270',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27270/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27270/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27270/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/27270',
#   'id': 2581319957,
#   'node_id': 'I_kwDOIPDwls6Z29EV',
#   'number': 27270,
#   'title': 'Map Reduce Chain bug: "TypeError: unsupported operand type(s) for +=: \'NoneType\' and \'NoneType\'"',
#   'user': {'login': 'flashzzz',
#    'id': 73419491,
#    'node_id': 'MDQ6VXNlcjczNDE5NDkx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73419491?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/flashzzz',
#    'html_url': 'https://github.com/flashzzz',
#    'followers_url': 'https://api.github.com/users/flashzzz/followers',
#    'following_url': 'https://api.github.com/users/flashzzz/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/flashzzz/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/flashzzz/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/flashzzz/subscriptions',
#    'organizations_url': 'https://api.github.com/users/flashzzz/orgs',
#    'repos_url': 'https://api.github.com/users/flashzzz/repos',
#    'events_url': 'https://api.github.com/users/flashzzz/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/flashzzz/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 6411661606,
#     'node_id': 'LA_kwDOIPDwls8AAAABfioxJg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/investigate',
#     'name': 'investigate',
#     'color': '4D8397',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-10-11T12:57:46Z',
#   'updated_at': '2024-10-11T13:02:01Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Checked other resources\n\n- [X] I added a very descriptive title to this issue.\n- [X] I searched the LangChain documentation with the integrated search.\n- [X] I used the GitHub search to find a similar question and didn\'t find it.\n- [X] I am sure that this is a bug in LangChain rather than my code.\n- [X] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\n\n### Example Code\n\n```\r\nfrom langchain.chains import (\r\n    StuffDocumentsChain, LLMChain, ReduceDocumentsChain, MapReduceChain\r\n)\r\nfrom langchain.chains.combine_documents.map_reduce import MapReduceDocumentsChain\r\nfrom langchain.text_splitter import CharacterTextSplitter\r\n\r\n\r\ndef baseChain(llm, chat_prompt, output_name):\r\n    base_chain = LLMChain(llm=llm[\'instance\'], prompt=chat_prompt, output_key=output_name, verbose=True)\r\n    return base_chain\r\n\r\n\r\ndef stuffDocChain(reduce_llm_chain):\r\n    combine_documents_chain = StuffDocumentsChain(\r\n        llm_chain=reduce_llm_chain,\r\n        document_variable_name="input_text",\r\n    )\r\n    return combine_documents_chain\r\n\r\n\r\n# Combines and iteravely reduces the mapped documents\r\ndef combine_and_reduce(combine_documents_chain, map_max_tokens):\r\n    reduce_documents_chain = ReduceDocumentsChain(\r\n        # This is final chain that is called.\r\n        combine_documents_chain=combine_documents_chain,\r\n        # If documents exceed context for `combine_documents_chain`\r\n        collapse_documents_chain=combine_documents_chain,\r\n        # The maximum number of tokens to group documents into\r\n        token_max=map_max_tokens)\r\n    return reduce_documents_chain\r\n\r\n\r\n# Combining documents by mapping a chain over them, then combining results with reduce chain\r\ndef map_reduce_step(map_llm_chain, reduce_documents_chain):\r\n    combine_documents = MapReduceDocumentsChain(\r\n        # Map chain\r\n        llm_chain=map_llm_chain,\r\n        # Reduce chain\r\n        reduce_documents_chain=reduce_documents_chain,\r\n        # The variable name in the llm_chain to put the documents in\r\n        document_variable_name="input_text")\r\n\r\n    return combine_documents\r\n\r\n\r\ndef mapReduceChain(combine_documents, chunk_size, chunk_overlap):\r\n    map_reduce = MapReduceChain(\r\n        combine_documents_chain=combine_documents,\r\n        text_splitter=CharacterTextSplitter(separator="", chunk_size=chunk_size, chunk_overlap=chunk_overlap),\r\n        verbose=True)  # TODO add seperator protos\r\n    return map_reduce\r\n\r\n\r\n\r\ndef run_map_chain(llm, map_prompt, combine_prompt, chunk_size, chunk_overlap, inputs, output_name, map_max_tokens, thread_logs):\r\n    # Processing to required prompt templates\r\n    chunk_prompt_template, combine_prompt_template = map_process_prompt(map_prompt, combine_prompt)\r\n\r\n    # LLM to use in map and reduce stages\r\n    map_llm_chain = baseChain(llm, chunk_prompt_template, output_name)\r\n    reduce_llm_chain = baseChain(llm, combine_prompt_template, output_name)\r\n\r\n    # Takes a list of documents and combines them into a single string\r\n    combine_documents_chain = stuffDocChain(reduce_llm_chain)\r\n\r\n    # Combines and iteravely reduces the mapped documents\r\n    reduce_documents_chain = combine_and_reduce(combine_documents_chain, map_max_tokens)\r\n\r\n    # Combining documents by mapping a chain over them, then combining results with reduce chain\r\n    combine_documents = map_reduce_step(map_llm_chain, reduce_documents_chain)\r\n\r\n    map_chain = mapReduceChain(combine_documents, chunk_size, chunk_overlap)\r\n\r\n    # Calculate input tokens\r\n    total_input = str(chunk_prompt_template) + str(combine_prompt_template) + str(inputs)\r\n    total_tokens = num_tokens_from_string(total_input, "cl100k_base")\r\n\r\n    logger.info(f"Total input tokens are: {total_tokens}")\r\n\r\n    with get_openai_callback() as cb:\r\n        sta ...
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27270/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27270/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27269',
#   'repository_url': 'https://api.github.com/repos/langchain-ai/langchain',
#   'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27269/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27269/comments',
#   'events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27269/events',
#   'html_url': 'https://github.com/langchain-ai/langchain/issues/27269',
#   'id': 2581094568,
#   'node_id': 'I_kwDOIPDwls6Z2GCo',
#   'number': 27269,
#   'title': '[Azure CosmosDB NoSQL] similarity_search_with_score function returning CosmosHttpResponseError "bad request"',
#   'user': {'login': 'peacemaker360',
#    'id': 31038013,
#    'node_id': 'MDQ6VXNlcjMxMDM4MDEz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31038013?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/peacemaker360',
#    'html_url': 'https://github.com/peacemaker360',
#    'followers_url': 'https://api.github.com/users/peacemaker360/followers',
#    'following_url': 'https://api.github.com/users/peacemaker360/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/peacemaker360/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/peacemaker360/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/peacemaker360/subscriptions',
#    'organizations_url': 'https://api.github.com/users/peacemaker360/orgs',
#    'repos_url': 'https://api.github.com/users/peacemaker360/repos',
#    'events_url': 'https://api.github.com/users/peacemaker360/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/peacemaker360/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 5541432778,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkuNyg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20vector%20store',
#     'name': 'Ɑ: vector store',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to vector store module'},
#    {'id': 6411661606,
#     'node_id': 'LA_kwDOIPDwls8AAAABfioxJg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/investigate',
#     'name': 'investigate',
#     'color': '4D8397',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-10-11T11:03:46Z',
#   'updated_at': '2024-10-11T11:06:01Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Checked other resources\n\n- [X] I added a very descriptive title to this issue.\n- [X] I searched the LangChain documentation with the integrated search.\n- [X] I used the GitHub search to find a similar question and didn\'t find it.\n- [X] I am sure that this is a bug in LangChain rather than my code.\n- [X] The bug is not resolved by updating to the latest stable version of LangChain (or the specific integration package).\n\n### Example Code\n\nSample for reproducing the issue\r\n```python\r\nimport os\r\nfrom dotenv import load_dotenv\r\nfrom azure.cosmos import CosmosClient, PartitionKey\r\nfrom langchain_community.vectorstores.azure_cosmos_db_no_sql import (\r\n    AzureCosmosDBNoSqlVectorSearch,\r\n)\r\nfrom langchain_openai import OpenAIEmbeddings\r\n\r\n# from azure_cosmos_db_no_sql import AzureCosmosDBNoSqlVectorSearch # workarround with modifications to code\r\n\r\n_ = load_dotenv()\r\n\r\nHOST = os.environ[\'AZURE_COSMOS_URL\']\r\nKEY = os.environ[\'AZURE_COSMOS_KEY\']\r\n\r\ncosmos_client = CosmosClient(HOST, KEY)\r\ndatabase_name = "db"\r\ncontainer_name = "container1"\r\npartition_key = PartitionKey(path="/id")\r\ncosmos_container_properties = {"partition_key": partition_key}\r\n\r\nopenai_embeddings = OpenAIEmbeddings(model="text-embedding-3-large")\r\n\r\nvectorstore = AzureCosmosDBNoSqlVectorSearch(\r\n    cosmos_client=cosmos_client,\r\n    embedding=openai_embeddings,\r\n    vector_embedding_policy={\r\n        "vectorEmbeddings": [\r\n            {\r\n                "path": "/embedding",\r\n                "dataType": "float32",\r\n                "distanceFunction": "cosine",\r\n                "dimensions": 3072,\r\n            }\r\n        ]\r\n    },\r\n    indexing_policy={\r\n        "indexingMode": "consistent",\r\n        "includedPaths": [{"path": "/*"}],\r\n        "excludedPaths": [{"path": \'/"_etag"/?\'}],\r\n        "vectorIndexes": [{"path": "/embedding", "type": "quantizedFlat"}],\r\n    },\r\n    cosmos_container_properties=cosmos_container_properties,\r\n    cosmos_database_properties={\'id\': database_name},\r\n    database_name=database_name,\r\n    container_name=container_name,\r\n    create_container=False,\r\n)\r\n\r\nquery = "What were the compute requirements for training GPT 4"\r\n\r\nresults = vectorstore.similarity_search_with_score(\r\n    query=query,\r\n)\r\n````\n\n### Error Message and Stack Trace (if applicable)\n\n{\r\n\t"name": "CosmosHttpResponseError",\r\n\t"message": "(BadRequest) One of the input values is invalid.\\r\r\nActivityId: 73e70e21-b8f3-4eb7-bb26-a85e03ae05fc, Windows/10.0.20348 cosmos-netstandard-sdk/3.18.0\r\nCode: BadRequest\r\nMessage: One of the input values is invalid.\\r\r\nActivityId: 73e70e21-b8f3-4eb7-bb26-a85e03ae05fc, Windows/10.0.20348 cosmos-netstandard-sdk/3.18.0",\r\n\t"stack": "---------------------------------------------------------------------------\r\nCosmosHttpResponseError                   Traceback (most recent call last)\r\nCell In[7], line 3\r\n      1 query = \\"What were the compute requirements for training GPT 4\\"\r\n----> 3 results = vectorstore.similarity_search_with_score(\r\n      4     query=query,\r\n      5     k=5,\r\n      6 )\r\n      8 # Display results\r\n      9 for result in results:\r\n\r\nFile ~/git/demos/.venv/lib/python3.10/site-packages/langchain_community/vectorstores/azure_cosmos_db_no_sql.py:322, in AzureCosmosDBNoSqlVectorSearch.similarity_search_with_score(self, query, k, pre_filter, with_embedding)\r\n    314 def similarity_search_with_score(\r\n    315     self,\r\n    316     query: str,\r\n   (...)\r\n    319     with_embedding: bool = False,\r\n    320 ) -> List[Tuple[Document, float]]:\r\n    321     embeddings = self._embedding.embed_query(query)\r\n--> 322     docs_and_scores = self._similarity_search_with_score(\r\n    323         embeddings=embeddings,\r\n    324         k=k,\r\n    325         pre_filter=pre_filter,\r\n    326         with_embedding=with_embedding,\r\n    32 ...
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27269/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27269/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %% [markdown]
# ### List Pull Requests API
#
# API完整文档说明见：https://docs.github.com/en/rest/pulls/pulls?apiVersion=2022-11-28#list-pull-requests
#
# **请求样例**：`GET /repos/{owner}/{repo}/pulls`;

# %%
pull_requests = github_client.fetch_pull_requests(repo)

# %%
pull_requests
# Out:
# [{'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27330',
#   'id': 2122102493,
#   'node_id': 'PR_kwDOIPDwls5-fLbd',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/27330',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/27330.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/27330.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27330',
#   'number': 27330,
#   'state': 'open',
#   'locked': False,
#   'title': 'community: Add support for clob datatype in oracle database',
#   'user': {'login': 'xsai9101',
#    'id': 158216624,
#    'node_id': 'U_kgDOCW4xsA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/158216624?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xsai9101',
#    'html_url': 'https://github.com/xsai9101',
#    'followers_url': 'https://api.github.com/users/xsai9101/followers',
#    'following_url': 'https://api.github.com/users/xsai9101/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/xsai9101/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/xsai9101/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/xsai9101/subscriptions',
#    'organizations_url': 'https://api.github.com/users/xsai9101/orgs',
#    'repos_url': 'https://api.github.com/users/xsai9101/repos',
#    'events_url': 'https://api.github.com/users/xsai9101/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/xsai9101/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'body': '**Description**:\r\nThis PR add support of clob/blob data type for oracle document loader, clob/blob can only be read by oracledb package when connection is open, so reformat code to process data before connection closes.\r\n\r\n**Dependencies**:\r\noracledb package same as before. pip install oracledb\r\n',
#   'created_at': '2024-10-14T06:22:50Z',
#   'updated_at': '2024-10-14T06:23:21Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': '423928b4d07307a9c75b8233df29c2ff09901e9c',
#   'assignee': None,
#   'assignees': [],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [{'id': 5541144676,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkcoZA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20doc%20loader',
#     'name': 'Ɑ: doc loader',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to document loader module (not documentation)'},
#    {'id': 6232714119,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rhw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:M',
#     'name': 'size:M',
#     'color': 'FEF2C0',
#     'default': False,
#     'description': 'This PR changes 30-99 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27330/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27330/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27330/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/e09cfc1135e39130bfaaac165316f32d9b49b328',
#   'head': {'label': 'xsai9101:langchain_adb_clob',
#    'ref': 'langchain_adb_clob',
#    'sha': 'e09cfc1135e39130bfaaac165316f32d9b49b328',
#    'user': {'login': 'xsai9101',
#     'id': 158216624,
#     'node_id': 'U_kgDOCW4xsA',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/158216624?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/xsai9101',
#     'html_url': 'https://github.com/xsai9101',
#     'followers_url': 'https://api.github.com/users/xsai9101/followers',
#     'following_url': 'https://api.github.com/users/xsai9101/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/xsai9101/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/xsai9101/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/xsai9101/subscriptions',
#     'organizations_url': 'https://api.github.com/users/xsai9101/orgs',
#     'repos_url': 'https://api.github.com/users/xsai9101/repos',
#     'events_url': 'https://api.github.com/users/xsai9101/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/xsai9101/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'repo': {'id': 777450394,
#     'node_id': 'R_kgDOLlbzmg',
#     'name': 'langchain_autonomous_database',
#     'full_name': 'xsai9101/langchain_autonomous_database',
#     'private': False,
#     'owner': {'login': 'xsai9101',
#      'id': 158216624,
#      'node_id': 'U_kgDOCW4xsA',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/158216624?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/xsai9101',
#      'html_url': 'https://github.com/xsai9101',
#      'followers_url': 'https://api.github.com/users/xsai9101/followers',
#      'following_url': 'https://api.github.com/users/xsai9101/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/xsai9101/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/xsai9101/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/xsai9101/subscriptions',
#      'organizations_url': 'https://api.github.com/users/xsai9101/orgs',
#      'repos_url': 'https://api.github.com/users/xsai9101/repos',
#      'events_url': 'https://api.github.com/users/xsai9101/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/xsai9101/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/xsai9101/langchain_autonomous_database',
#     'description': '🦜🔗 Langchain Integration with Autonomous Database',
#     'fork': True,
#     'url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database',
#     'forks_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/forks',
#     'keys_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/teams',
#     'hooks_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/hooks',
#     'issue_events_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/events',
#     'assignees_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/tags',
#     'blobs_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/languages',
#     'stargazers_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/stargazers',
#     'contributors_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/contributors',
#     'subscribers_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/subscribers',
#     'subscription_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/subscription',
#     'commits_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/merges',
#     'archive_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/downloads',
#     'issues_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/xsai9101/langchain_autonomous_database/deployments',
#     'created_at': '2024-03-25T21:50:57Z',
#     'updated_at': '2024-10-14T05:27:52Z',
#     'pushed_at': '2024-10-14T06:15:54Z',
#     'git_url': 'git://github.com/xsai9101/langchain_autonomous_database.git',
#     'ssh_url': 'git@github.com:xsai9101/langchain_autonomous_database.git',
#     'clone_url': 'https://github.com/xsai9101/langchain_autonomous_database.git',
#     'svn_url': 'https://github.com/xsai9101/langchain_autonomous_database',
#     'homepage': 'https://python.langchain.com',
#     'size': 251682,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': 'Jupyter Notebook',
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': '2197958366b527df23adbf12bf6578e4cd5e002c',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-10-14T07:49:05Z',
#     'pushed_at': '2024-10-11T22:14:47Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 309806,
#     'stargazers_count': 93452,
#     'watchers_count': 93452,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 15046,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 819,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 15046,
#     'open_issues': 819,
#     'watchers': 93452,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27330'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/27330'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/27330'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/27330/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27330/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27330/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/e09cfc1135e39130bfaaac165316f32d9b49b328'}},
#   'author_association': 'CONTRIBUTOR',
#   'auto_merge': None,
#   'active_lock_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27329',
#   'id': 2122095947,
#   'node_id': 'PR_kwDOIPDwls5-fJ1L',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/27329',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/27329.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/27329.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27329',
#   'number': 27329,
#   'state': 'open',
#   'locked': False,
#   'title': 'LangChain Community: VectorStores: Azure Cosmos DB Mongo vCore with DiskANN',
#   'user': {'login': 'fatmelon',
#    'id': 9691826,
#    'node_id': 'MDQ6VXNlcjk2OTE4MjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9691826?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fatmelon',
#    'html_url': 'https://github.com/fatmelon',
#    'followers_url': 'https://api.github.com/users/fatmelon/followers',
#    'following_url': 'https://api.github.com/users/fatmelon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fatmelon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fatmelon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fatmelon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fatmelon/orgs',
#    'repos_url': 'https://api.github.com/users/fatmelon/repos',
#    'events_url': 'https://api.github.com/users/fatmelon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/fatmelon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'body': '# Description\r\nAdd a new vector index type `diskann` to Azure Cosmos DB Mongo vCore vector store. Paper of DiskANN can be found here [DiskANN: Fast Accurate Billion-point Nearest Neighbor Search on a Single Node](https://proceedings.neurips.cc/paper_files/paper/2019/file/09853c7fb1d3f8ee67a61b6bf4a7f8e6-Paper.pdf).\r\n\r\n## Sample Usage\r\n```python\r\nfrom pymongo import MongoClient\r\n\r\n# INDEX_NAME = "izzy-test-index-2"\r\n# NAMESPACE = "izzy_test_db.izzy_test_collection"\r\n# DB_NAME, COLLECTION_NAME = NAMESPACE.split(".")\r\n\r\nclient: MongoClient = MongoClient(CONNECTION_STRING)\r\ncollection = client[DB_NAME][COLLECTION_NAME]\r\n\r\nmodel_deployment = os.getenv(\r\n    "OPENAI_EMBEDDINGS_DEPLOYMENT", "smart-agent-embedding-ada"\r\n)\r\nmodel_name = os.getenv("OPENAI_EMBEDDINGS_MODEL_NAME", "text-embedding-ada-002")\r\n\r\nvectorstore = AzureCosmosDBVectorSearch.from_documents(\r\n    docs,\r\n    openai_embeddings,\r\n    collection=collection,\r\n    index_name=INDEX_NAME,\r\n)\r\n\r\n# Read more about these variables in detail here. https://learn.microsoft.com/en-us/azure/cosmos-db/mongodb/vcore/vector-search\r\nmaxDegree = 40\r\ndimensions = 1536\r\nsimilarity_algorithm = CosmosDBSimilarityType.COS\r\nkind = CosmosDBVectorSearchType.VECTOR_HNSW\r\nlBuild = 20\r\n\r\nvectorstore.create_index(\r\n            dimensions=dimensions,\r\n            similarity=similarity_algorithm,\r\n            kind=kind ,\r\n            max_degree=maxDegree,\r\n            l_build=lBuild,\r\n        )\r\n```\r\n\r\n## Dependencies\r\nNo additional dependencies were added',
#   'created_at': '2024-10-14T06:19:40Z',
#   'updated_at': '2024-10-14T06:44:58Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': '522f88f82d6bd019a2fe0977c3d6ebc2877385ca',
#   'assignee': None,
#   'assignees': [],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [{'id': 5541432778,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkuNyg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20vector%20store',
#     'name': 'Ɑ: vector store',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to vector store module'},
#    {'id': 6232714130,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-rkg',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XL',
#     'name': 'size:XL',
#     'color': 'E99695',
#     'default': False,
#     'description': 'This PR changes 500-999 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27329/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27329/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27329/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/349ccd8242fdf01291c261e583c576456cb9ed94',
#   'head': {'label': 'fatmelon:yangqiao/AddDiskANN',
#    'ref': 'yangqiao/AddDiskANN',
#    'sha': '349ccd8242fdf01291c261e583c576456cb9ed94',
#    'user': {'login': 'fatmelon',
#     'id': 9691826,
#     'node_id': 'MDQ6VXNlcjk2OTE4MjY=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/9691826?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/fatmelon',
#     'html_url': 'https://github.com/fatmelon',
#     'followers_url': 'https://api.github.com/users/fatmelon/followers',
#     'following_url': 'https://api.github.com/users/fatmelon/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/fatmelon/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/fatmelon/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/fatmelon/subscriptions',
#     'organizations_url': 'https://api.github.com/users/fatmelon/orgs',
#     'repos_url': 'https://api.github.com/users/fatmelon/repos',
#     'events_url': 'https://api.github.com/users/fatmelon/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/fatmelon/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'repo': {'id': 850932353,
#     'node_id': 'R_kgDOMrgygQ',
#     'name': 'langchain',
#     'full_name': 'fatmelon/langchain',
#     'private': False,
#     'owner': {'login': 'fatmelon',
#      'id': 9691826,
#      'node_id': 'MDQ6VXNlcjk2OTE4MjY=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/9691826?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/fatmelon',
#      'html_url': 'https://github.com/fatmelon',
#      'followers_url': 'https://api.github.com/users/fatmelon/followers',
#      'following_url': 'https://api.github.com/users/fatmelon/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/fatmelon/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/fatmelon/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/fatmelon/subscriptions',
#      'organizations_url': 'https://api.github.com/users/fatmelon/orgs',
#      'repos_url': 'https://api.github.com/users/fatmelon/repos',
#      'events_url': 'https://api.github.com/users/fatmelon/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/fatmelon/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/fatmelon/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': True,
#     'url': 'https://api.github.com/repos/fatmelon/langchain',
#     'forks_url': 'https://api.github.com/repos/fatmelon/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/fatmelon/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/fatmelon/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/fatmelon/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/fatmelon/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/fatmelon/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/fatmelon/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/fatmelon/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/fatmelon/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/fatmelon/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/fatmelon/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/fatmelon/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/fatmelon/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/fatmelon/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/fatmelon/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/fatmelon/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/fatmelon/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/fatmelon/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/fatmelon/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/fatmelon/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/fatmelon/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/fatmelon/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/fatmelon/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/fatmelon/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/fatmelon/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/fatmelon/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/fatmelon/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/fatmelon/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/fatmelon/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/fatmelon/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/fatmelon/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/fatmelon/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/fatmelon/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/fatmelon/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/fatmelon/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/fatmelon/langchain/deployments',
#     'created_at': '2024-09-02T05:38:22Z',
#     'updated_at': '2024-10-11T05:58:56Z',
#     'pushed_at': '2024-10-14T06:41:25Z',
#     'git_url': 'git://github.com/fatmelon/langchain.git',
#     'ssh_url': 'git@github.com:fatmelon/langchain.git',
#     'clone_url': 'https://github.com/fatmelon/langchain.git',
#     'svn_url': 'https://github.com/fatmelon/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 251720,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': 'Jupyter Notebook',
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': '2197958366b527df23adbf12bf6578e4cd5e002c',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-10-14T07:49:05Z',
#     'pushed_at': '2024-10-11T22:14:47Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 309806,
#     'stargazers_count': 93452,
#     'watchers_count': 93452,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 15046,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 819,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 15046,
#     'open_issues': 819,
#     'watchers': 93452,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27329'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/27329'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/27329'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/27329/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27329/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27329/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/349ccd8242fdf01291c261e583c576456cb9ed94'}},
#   'author_association': 'NONE',
#   'auto_merge': None,
#   'active_lock_reason': None},
#  {'url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27327',
#   'id': 2121913648,
#   'node_id': 'PR_kwDOIPDwls5-edUw',
#   'html_url': 'https://github.com/langchain-ai/langchain/pull/27327',
#   'diff_url': 'https://github.com/langchain-ai/langchain/pull/27327.diff',
#   'patch_url': 'https://github.com/langchain-ai/langchain/pull/27327.patch',
#   'issue_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27327',
#   'number': 27327,
#   'state': 'open',
#   'locked': False,
#   'title': 'community: fixes json loader not getting texts with json standard',
#   'user': {'login': 'TonyBotongChu',
#    'id': 19709245,
#    'node_id': 'MDQ6VXNlcjE5NzA5MjQ1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19709245?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TonyBotongChu',
#    'html_url': 'https://github.com/TonyBotongChu',
#    'followers_url': 'https://api.github.com/users/TonyBotongChu/followers',
#    'following_url': 'https://api.github.com/users/TonyBotongChu/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/TonyBotongChu/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/TonyBotongChu/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/TonyBotongChu/subscriptions',
#    'organizations_url': 'https://api.github.com/users/TonyBotongChu/orgs',
#    'repos_url': 'https://api.github.com/users/TonyBotongChu/repos',
#    'events_url': 'https://api.github.com/users/TonyBotongChu/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/TonyBotongChu/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'body': 'This PR fixes JSONLoader._get_text not converting objects to json string correctly.\r\nIf an object is serializable and is not a dict, JSONLoader will use python built-in str() method to convert it to string. This may cause object converted to strings not following json standard. For example, a list will be converted to string with single quotes, and if json.loads try to load this string, it will cause error.\r\n',
#   'created_at': '2024-10-14T04:05:35Z',
#   'updated_at': '2024-10-14T04:05:56Z',
#   'closed_at': None,
#   'merged_at': None,
#   'merge_commit_sha': 'cd7f9387fb6e0b2f511daa7a7eea00b21a9d27c4',
#   'assignee': None,
#   'assignees': [],
#   'requested_reviewers': [],
#   'requested_teams': [],
#   'labels': [{'id': 5541144676,
#     'node_id': 'LA_kwDOIPDwls8AAAABSkcoZA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%E2%B1%AD:%20doc%20loader',
#     'name': 'Ɑ: doc loader',
#     'color': 'D4C5F9',
#     'default': False,
#     'description': 'Related to document loader module (not documentation)'},
#    {'id': 5680700839,
#     'node_id': 'LA_kwDOIPDwls8AAAABUpidpw',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/%F0%9F%A4%96:bug',
#     'name': '🤖:bug',
#     'color': 'F9D0C4',
#     'default': False,
#     'description': 'Related to a bug, vulnerability, unexpected error with an existing feature'},
#    {'id': 6232714104,
#     'node_id': 'LA_kwDOIPDwls8AAAABc3-reA',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/size:XS',
#     'name': 'size:XS',
#     'color': 'C2E0C6',
#     'default': False,
#     'description': 'This PR changes 0-9 lines, ignoring generated files.'},
#    {'id': 7097373342,
#     'node_id': 'LA_kwDOIPDwls8AAAABpwlSng',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/labels/community',
#     'name': 'community',
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27327/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27327/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27327/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/440c3bca89f1ef76fb8c39459ce50b760c08d974',
#   'head': {'label': 'TonyBotongChu:fix-json-loader',
#    'ref': 'fix-json-loader',
#    'sha': '440c3bca89f1ef76fb8c39459ce50b760c08d974',
#    'user': {'login': 'TonyBotongChu',
#     'id': 19709245,
#     'node_id': 'MDQ6VXNlcjE5NzA5MjQ1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/19709245?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/TonyBotongChu',
#     'html_url': 'https://github.com/TonyBotongChu',
#     'followers_url': 'https://api.github.com/users/TonyBotongChu/followers',
#     'following_url': 'https://api.github.com/users/TonyBotongChu/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/TonyBotongChu/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/TonyBotongChu/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/TonyBotongChu/subscriptions',
#     'organizations_url': 'https://api.github.com/users/TonyBotongChu/orgs',
#     'repos_url': 'https://api.github.com/users/TonyBotongChu/repos',
#     'events_url': 'https://api.github.com/users/TonyBotongChu/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/TonyBotongChu/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'repo': {'id': 872206705,
#     'node_id': 'R_kgDOM_zRcQ',
#     'name': 'langchain',
#     'full_name': 'TonyBotongChu/langchain',
#     'private': False,
#     'owner': {'login': 'TonyBotongChu',
#      'id': 19709245,
#      'node_id': 'MDQ6VXNlcjE5NzA5MjQ1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/19709245?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/TonyBotongChu',
#      'html_url': 'https://github.com/TonyBotongChu',
#      'followers_url': 'https://api.github.com/users/TonyBotongChu/followers',
#      'following_url': 'https://api.github.com/users/TonyBotongChu/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/TonyBotongChu/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/TonyBotongChu/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/TonyBotongChu/subscriptions',
#      'organizations_url': 'https://api.github.com/users/TonyBotongChu/orgs',
#      'repos_url': 'https://api.github.com/users/TonyBotongChu/repos',
#      'events_url': 'https://api.github.com/users/TonyBotongChu/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/TonyBotongChu/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/TonyBotongChu/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': True,
#     'url': 'https://api.github.com/repos/TonyBotongChu/langchain',
#     'forks_url': 'https://api.github.com/repos/TonyBotongChu/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/TonyBotongChu/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/TonyBotongChu/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/TonyBotongChu/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/TonyBotongChu/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/TonyBotongChu/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/TonyBotongChu/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/TonyBotongChu/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/TonyBotongChu/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/TonyBotongChu/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/TonyBotongChu/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/TonyBotongChu/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/TonyBotongChu/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/TonyBotongChu/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/TonyBotongChu/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/TonyBotongChu/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/TonyBotongChu/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/TonyBotongChu/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/TonyBotongChu/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/TonyBotongChu/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/TonyBotongChu/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/TonyBotongChu/langchain/git/commits{/sha}',
# ...
#     'color': '579082',
#     'default': False,
#     'description': 'Related to langchain-community'}],
#   'milestone': None,
#   'draft': False,
#   'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27230/commits',
#   'review_comments_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27230/comments',
#   'review_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/27230/comments',
#   'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/857c7b3a286b0faae013e5c10a0a143798871934',
#   'head': {'label': 'predictionguard:master',
#    'ref': 'master',
#    'sha': '857c7b3a286b0faae013e5c10a0a143798871934',
#    'user': {'login': 'predictionguard',
#     'id': 118856305,
#     'node_id': 'O_kgDOBxWacQ',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/118856305?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/predictionguard',
#     'html_url': 'https://github.com/predictionguard',
#     'followers_url': 'https://api.github.com/users/predictionguard/followers',
#     'following_url': 'https://api.github.com/users/predictionguard/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/predictionguard/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/predictionguard/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/predictionguard/subscriptions',
#     'organizations_url': 'https://api.github.com/users/predictionguard/orgs',
#     'repos_url': 'https://api.github.com/users/predictionguard/repos',
#     'events_url': 'https://api.github.com/users/predictionguard/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/predictionguard/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 830640301,
#     'node_id': 'R_kgDOMYKQrQ',
#     'name': 'langchain',
#     'full_name': 'predictionguard/langchain',
#     'private': False,
#     'owner': {'login': 'predictionguard',
#      'id': 118856305,
#      'node_id': 'O_kgDOBxWacQ',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/118856305?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/predictionguard',
#      'html_url': 'https://github.com/predictionguard',
#      'followers_url': 'https://api.github.com/users/predictionguard/followers',
#      'following_url': 'https://api.github.com/users/predictionguard/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/predictionguard/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/predictionguard/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/predictionguard/subscriptions',
#      'organizations_url': 'https://api.github.com/users/predictionguard/orgs',
#      'repos_url': 'https://api.github.com/users/predictionguard/repos',
#      'events_url': 'https://api.github.com/users/predictionguard/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/predictionguard/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/predictionguard/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': True,
#     'url': 'https://api.github.com/repos/predictionguard/langchain',
#     'forks_url': 'https://api.github.com/repos/predictionguard/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/predictionguard/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/predictionguard/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/predictionguard/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/predictionguard/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/predictionguard/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/predictionguard/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/predictionguard/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/predictionguard/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/predictionguard/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/predictionguard/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/predictionguard/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/predictionguard/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/predictionguard/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/predictionguard/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/predictionguard/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/predictionguard/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/predictionguard/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/predictionguard/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/predictionguard/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/predictionguard/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/predictionguard/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/predictionguard/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/predictionguard/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/predictionguard/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/predictionguard/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/predictionguard/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/predictionguard/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/predictionguard/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/predictionguard/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/predictionguard/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/predictionguard/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/predictionguard/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/predictionguard/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/predictionguard/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/predictionguard/langchain/deployments',
#     'created_at': '2024-07-18T17:05:08Z',
#     'updated_at': '2024-10-09T16:00:46Z',
#     'pushed_at': '2024-10-09T16:00:43Z',
#     'git_url': 'git://github.com/predictionguard/langchain.git',
#     'ssh_url': 'git@github.com:predictionguard/langchain.git',
#     'clone_url': 'https://github.com/predictionguard/langchain.git',
#     'svn_url': 'https://github.com/predictionguard/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 249928,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': 'Jupyter Notebook',
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master'}},
#   'base': {'label': 'langchain-ai:master',
#    'ref': 'master',
#    'sha': '5b9b8fe80f70af5a627630c1abc3b809b2e2ba26',
#    'user': {'login': 'langchain-ai',
#     'id': 126733545,
#     'node_id': 'O_kgDOB43M6Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/langchain-ai',
#     'html_url': 'https://github.com/langchain-ai',
#     'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#     'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#     'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#     'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#     'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'repo': {'id': 552661142,
#     'node_id': 'R_kgDOIPDwlg',
#     'name': 'langchain',
#     'full_name': 'langchain-ai/langchain',
#     'private': False,
#     'owner': {'login': 'langchain-ai',
#      'id': 126733545,
#      'node_id': 'O_kgDOB43M6Q',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/126733545?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/langchain-ai',
#      'html_url': 'https://github.com/langchain-ai',
#      'followers_url': 'https://api.github.com/users/langchain-ai/followers',
#      'following_url': 'https://api.github.com/users/langchain-ai/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/langchain-ai/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/langchain-ai/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/langchain-ai/subscriptions',
#      'organizations_url': 'https://api.github.com/users/langchain-ai/orgs',
#      'repos_url': 'https://api.github.com/users/langchain-ai/repos',
#      'events_url': 'https://api.github.com/users/langchain-ai/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/langchain-ai/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/langchain-ai/langchain',
#     'description': '🦜🔗 Build context-aware reasoning applications',
#     'fork': False,
#     'url': 'https://api.github.com/repos/langchain-ai/langchain',
#     'forks_url': 'https://api.github.com/repos/langchain-ai/langchain/forks',
#     'keys_url': 'https://api.github.com/repos/langchain-ai/langchain/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/langchain-ai/langchain/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/langchain-ai/langchain/teams',
#     'hooks_url': 'https://api.github.com/repos/langchain-ai/langchain/hooks',
#     'issue_events_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/langchain-ai/langchain/events',
#     'assignees_url': 'https://api.github.com/repos/langchain-ai/langchain/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/langchain-ai/langchain/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/langchain-ai/langchain/tags',
#     'blobs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/langchain-ai/langchain/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/langchain-ai/langchain/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/langchain-ai/langchain/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/langchain-ai/langchain/languages',
#     'stargazers_url': 'https://api.github.com/repos/langchain-ai/langchain/stargazers',
#     'contributors_url': 'https://api.github.com/repos/langchain-ai/langchain/contributors',
#     'subscribers_url': 'https://api.github.com/repos/langchain-ai/langchain/subscribers',
#     'subscription_url': 'https://api.github.com/repos/langchain-ai/langchain/subscription',
#     'commits_url': 'https://api.github.com/repos/langchain-ai/langchain/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/langchain-ai/langchain/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/langchain-ai/langchain/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/langchain-ai/langchain/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/langchain-ai/langchain/merges',
#     'archive_url': 'https://api.github.com/repos/langchain-ai/langchain/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/langchain-ai/langchain/downloads',
#     'issues_url': 'https://api.github.com/repos/langchain-ai/langchain/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/langchain-ai/langchain/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/langchain-ai/langchain/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/langchain-ai/langchain/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/langchain-ai/langchain/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/langchain-ai/langchain/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/langchain-ai/langchain/deployments',
#     'created_at': '2022-10-17T02:58:36Z',
#     'updated_at': '2024-10-14T07:49:05Z',
#     'pushed_at': '2024-10-11T22:14:47Z',
#     'git_url': 'git://github.com/langchain-ai/langchain.git',
#     'ssh_url': 'git@github.com:langchain-ai/langchain.git',
#     'clone_url': 'https://github.com/langchain-ai/langchain.git',
#     'svn_url': 'https://github.com/langchain-ai/langchain',
#     'homepage': 'https://python.langchain.com',
#     'size': 309806,
#     'stargazers_count': 93452,
#     'watchers_count': 93452,
#     'language': 'Jupyter Notebook',
#     'has_issues': True,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'has_discussions': True,
#     'forks_count': 15046,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 819,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 15046,
#     'open_issues': 819,
#     'watchers': 93452,
#     'default_branch': 'master'}},
#   '_links': {'self': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27230'},
#    'html': {'href': 'https://github.com/langchain-ai/langchain/pull/27230'},
#    'issue': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/27230'},
#    'comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/issues/27230/comments'},
#    'review_comments': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27230/comments'},
#    'review_comment': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/comments{/number}'},
#    'commits': {'href': 'https://api.github.com/repos/langchain-ai/langchain/pulls/27230/commits'},
#    'statuses': {'href': 'https://api.github.com/repos/langchain-ai/langchain/statuses/857c7b3a286b0faae013e5c10a0a143798871934'}},
#   'author_association': 'NONE',
#   'auto_merge': None,
#   'active_lock_reason': None}]

# %% [markdown]
# ### List Commits API
#
# API完整文档说明见：https://docs.github.com/en/rest/commits/commits?apiVersion=2022-11-28
#
# **请求样例**：`GET /repos/{owner}/{repo}/commits`;

# %%
commits = github_client.fetch_commits(repo)

# %%
commits
# Out:
# [{'sha': '2197958366b527df23adbf12bf6578e4cd5e002c',
#   'node_id': 'C_kwDOIPDwltoAKDIxOTc5NTgzNjZiNTI3ZGYyM2FkYmYxMmJmNjU3OGU0Y2Q1ZTAwMmM',
#   'commit': {'author': {'name': 'Erick Friis',
#     'email': 'erick@langchain.dev',
#     'date': '2024-10-11T22:14:45Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-10-11T22:14:45Z'},
#    'message': 'docs: add discussions with giscus (#27172)',
#    'tree': {'sha': '429bc492f572b7f2c5e61770bf5f7deeaed8b0c4',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/429bc492f572b7f2c5e61770bf5f7deeaed8b0c4'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/2197958366b527df23adbf12bf6578e4cd5e002c',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nFY+MVr/A+dnqo8LwXWbv\n=vY+C\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 429bc492f572b7f2c5e61770bf5f7deeaed8b0c4\nparent 56472769985b50f2ecdf2e8a8deb42805c5903d1\nauthor Erick Friis <erick@langchain.dev> 1728684885 -0700\ncommitter GitHub <noreply@github.com> 1728684885 -0700\n\ndocs: add discussions with giscus (#27172)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/2197958366b527df23adbf12bf6578e4cd5e002c',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/2197958366b527df23adbf12bf6578e4cd5e002c',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/2197958366b527df23adbf12bf6578e4cd5e002c/comments',
#   'author': {'login': 'efriis',
#    'id': 9557659,
#    'node_id': 'MDQ6VXNlcjk1NTc2NTk=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9557659?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/efriis',
#    'html_url': 'https://github.com/efriis',
#    'followers_url': 'https://api.github.com/users/efriis/followers',
#    'following_url': 'https://api.github.com/users/efriis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/efriis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/efriis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/efriis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/efriis/orgs',
#    'repos_url': 'https://api.github.com/users/efriis/repos',
#    'events_url': 'https://api.github.com/users/efriis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/efriis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '56472769985b50f2ecdf2e8a8deb42805c5903d1',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/56472769985b50f2ecdf2e8a8deb42805c5903d1',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/56472769985b50f2ecdf2e8a8deb42805c5903d1'}]},
#  {'sha': '56472769985b50f2ecdf2e8a8deb42805c5903d1',
#   'node_id': 'C_kwDOIPDwltoAKDU2NDcyNzY5OTg1YjUwZjJlY2RmMmU4YThkZWI0MjgwNWM1OTAzZDE',
#   'commit': {'author': {'name': 'Marcelo Nunes Alves',
#     'email': 'mnaweb@gmail.com',
#     'date': '2024-10-11T18:54:50Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-10-11T18:54:50Z'},
#    'message': 'community: Problem with embeddings in new versions of clickhouse. (#26041)\n\nStarting with Clickhouse version 24.8, a different type of configuration\r\nhas been introduced in the vectorized data ingestion, and if this\r\nconfiguration occurs, an error occurs when generating the table. As can\r\nbe seen below:\r\n\r\n![Screenshot from 2024-09-04\r\n11-48-00](https://github.com/user-attachments/assets/70840a93-1001-490c-921a-26924c51d9eb)\r\n\r\n---------\r\n\r\nCo-authored-by: Erick Friis <erick@langchain.dev>',
#    'tree': {'sha': '19c63be94162cbe9baac8b31575b142634211a13',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/19c63be94162cbe9baac8b31575b142634211a13'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/56472769985b50f2ecdf2e8a8deb42805c5903d1',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\neM87AO5vKS9BjjzjFspY\n=WMHd\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 19c63be94162cbe9baac8b31575b142634211a13\nparent 2a1029c53c9c14b177eb61743dc0501f97dd0738\nauthor Marcelo Nunes Alves <mnaweb@gmail.com> 1728672890 -0300\ncommitter GitHub <noreply@github.com> 1728672890 +0000\n\ncommunity: Problem with embeddings in new versions of clickhouse. (#26041)\n\nStarting with Clickhouse version 24.8, a different type of configuration\r\nhas been introduced in the vectorized data ingestion, and if this\r\nconfiguration occurs, an error occurs when generating the table. As can\r\nbe seen below:\r\n\r\n![Screenshot from 2024-09-04\r\n11-48-00](https://github.com/user-attachments/assets/70840a93-1001-490c-921a-26924c51d9eb)\r\n\r\n---------\r\n\r\nCo-authored-by: Erick Friis <erick@langchain.dev>'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/56472769985b50f2ecdf2e8a8deb42805c5903d1',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/56472769985b50f2ecdf2e8a8deb42805c5903d1',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/56472769985b50f2ecdf2e8a8deb42805c5903d1/comments',
#   'author': {'login': 'MarceloNunesAlves',
#    'id': 35287700,
#    'node_id': 'MDQ6VXNlcjM1Mjg3NzAw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35287700?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarceloNunesAlves',
#    'html_url': 'https://github.com/MarceloNunesAlves',
#    'followers_url': 'https://api.github.com/users/MarceloNunesAlves/followers',
#    'following_url': 'https://api.github.com/users/MarceloNunesAlves/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarceloNunesAlves/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarceloNunesAlves/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarceloNunesAlves/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarceloNunesAlves/orgs',
#    'repos_url': 'https://api.github.com/users/MarceloNunesAlves/repos',
#    'events_url': 'https://api.github.com/users/MarceloNunesAlves/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarceloNunesAlves/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '2a1029c53c9c14b177eb61743dc0501f97dd0738',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/2a1029c53c9c14b177eb61743dc0501f97dd0738',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/2a1029c53c9c14b177eb61743dc0501f97dd0738'}]},
#  {'sha': '2a1029c53c9c14b177eb61743dc0501f97dd0738',
#   'node_id': 'C_kwDOIPDwltoAKDJhMTAyOWM1M2M5YzE0YjE3N2ViNjE3NDNkYzA1MDFmOTdkZDA3Mzg',
#   'commit': {'author': {'name': 'Sir Qasim',
#     'email': 'm.qasim077@gmail.com',
#     'date': '2024-10-10T18:03:10Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-10-10T18:03:10Z'},
#    'message': 'Update chatbot.ipynb (#27243)\n\nAsync invocation:\r\nremove : from at the end of line \r\nline 441 because there is not any structure block after it.\r\n\r\nThank you for contributing to LangChain!\r\n\r\n- [ ] **PR title**: "package: description"\r\n- Where "package" is whichever of langchain, community, core, etc. is\r\nbeing modified. Use "docs: ..." for purely docs changes, "templates:\r\n..." for template changes, "infra: ..." for CI changes.\r\n  - Example: "community: add foobar LLM"\r\n\r\n\r\n- [ ] **PR message**: ***Delete this entire checklist*** and replace\r\nwith\r\n    - **Description:** a description of the change\r\n    - **Issue:** the issue # it fixes, if applicable\r\n    - **Dependencies:** any dependencies required for this change\r\n- **Twitter handle:** if your PR gets announced, and you\'d like a\r\nmention, we\'ll gladly shout you out!\r\n\r\n\r\n- [ ] **Add tests and docs**: If you\'re adding a new integration, please\r\ninclude\r\n1. a test for the integration, preferably unit tests that do not rely on\r\nnetwork access,\r\n2. an example notebook showing its use. It lives in\r\n`docs/docs/integrations` directory.\r\n\r\n\r\n- [ ] **Lint and test**: Run `make format`, `make lint` and `make test`\r\nfrom the root of the package(s) you\'ve modified. See contribution\r\nguidelines for more: https://python.langchain.com/docs/contributing/\r\n\r\nAdditional guidelines:\r\n- Make sure optional dependencies are imported within a function.\r\n- Please do not add dependencies to pyproject.toml files (even optional\r\nones) unless they are required for unit tests.\r\n- Most PRs should not touch more than one package.\r\n- Changes should be backwards compatible.\r\n- If you are adding something to community, do not re-import it in\r\nlangchain.\r\n\r\nIf no one reviews your PR within a few days, please @-mention one of\r\nbaskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.',
#    'tree': {'sha': 'ed788a198dfff9cebfc9d0ed5391a7116dc64dce',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/ed788a198dfff9cebfc9d0ed5391a7116dc64dce'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/2a1029c53c9c14b177eb61743dc0501f97dd0738',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n1PSv/L8VOTMtgdfOcdnH\n=gUdp\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree ed788a198dfff9cebfc9d0ed5391a7116dc64dce\nparent 5b9b8fe80f70af5a627630c1abc3b809b2e2ba26\nauthor Sir Qasim <m.qasim077@gmail.com> 1728583390 +0500\ncommitter GitHub <noreply@github.com> 1728583390 +0000\n\nUpdate chatbot.ipynb (#27243)\n\nAsync invocation:\r\nremove : from at the end of line \r\nline 441 because there is not any structure block after it.\r\n\r\nThank you for contributing to LangChain!\r\n\r\n- [ ] **PR title**: "package: description"\r\n- Where "package" is whichever of langchain, community, core, etc. is\r\nbeing modified. Use "docs: ..." for purely docs changes, "templates:\r\n..." for template changes, "infra: ..." for CI changes.\r\n  - Example: "community: add foobar LLM"\r\n\r\n\r\n- [ ] **PR message**: ***Delete this entire checklist*** and replace\r\nwith\r\n    - **Description:** a description of the change\r\n    - **Issue:** the issue # it fixes, if applicable\r\n    - **Dependencies:** any dependencies required for this change\r\n- **Twitter handle:** if your PR gets announced, and you\'d like a\r\nmention, we\'ll gladly shout you out!\r\n\r\n\r\n- [ ] **Add tests and docs**: If you\'re adding a new integration, please\r\ninclude\r\n1. a test for the integration, preferably unit tests that do not rely on\r\nnetwork access,\r\n2. an example notebook showing its use. It lives in\r\n`docs/docs/integrations` directory.\r\n\r\n\r\n- [ ] **Lint and test**: Run `make format`, `make lint` and `make test`\r\nfrom the root of the package(s) you\'ve modified. See contribution\r\nguidelines for more: https://python.langchain.com/docs/contributing/\r\n\r\nAdditional guidelines:\r\n- Make sure optional dependencies are imported within a function.\r\n- Please do not add dependencies to pyproject.toml files (even optional\r\nones) unless they are required for unit tests.\r\n- Most PRs should not touch more than one package.\r\n- Changes should be backwards compatible.\r\n- If you are adding something to community, do not re-import it in\r\nlangchain.\r\n\r\nIf no one reviews your PR within a few days, please @-mention one of\r\nbaskaryan, efriis, eyurtsev, ccurme, vbarda, hwchase17.'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/2a1029c53c9c14b177eb61743dc0501f97dd0738',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/2a1029c53c9c14b177eb61743dc0501f97dd0738',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/2a1029c53c9c14b177eb61743dc0501f97dd0738/comments',
#   'author': {'login': 'EnggQasim',
#    'id': 10209765,
#    'node_id': 'MDQ6VXNlcjEwMjA5NzY1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10209765?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/EnggQasim',
#    'html_url': 'https://github.com/EnggQasim',
#    'followers_url': 'https://api.github.com/users/EnggQasim/followers',
#    'following_url': 'https://api.github.com/users/EnggQasim/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/EnggQasim/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/EnggQasim/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/EnggQasim/subscriptions',
#    'organizations_url': 'https://api.github.com/users/EnggQasim/orgs',
#    'repos_url': 'https://api.github.com/users/EnggQasim/repos',
#    'events_url': 'https://api.github.com/users/EnggQasim/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/EnggQasim/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '5b9b8fe80f70af5a627630c1abc3b809b2e2ba26',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/5b9b8fe80f70af5a627630c1abc3b809b2e2ba26',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/5b9b8fe80f70af5a627630c1abc3b809b2e2ba26'}]},
#  {'sha': '5b9b8fe80f70af5a627630c1abc3b809b2e2ba26',
#   'node_id': 'C_kwDOIPDwltoAKDViOWI4ZmU4MGY3MGFmNWE2Mjc2MzBjMWFiYzNiODA5YjJlMmJhMjY',
#   'commit': {'author': {'name': 'Eugene Yurtsev',
#     'email': 'eyurtsev@gmail.com',
#     'date': '2024-10-09T15:25:58Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-10-09T15:25:58Z'},
#    'message': 'core[patch]: Ignore ASYNC110 to upgrade to newest ruff version (#27229)\n\nIgnoring ASYNC110 with explanation',
#    'tree': {'sha': '5884de4f731aae8a2872ad813a9b5b98c4b15484',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/5884de4f731aae8a2872ad813a9b5b98c4b15484'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/5b9b8fe80f70af5a627630c1abc3b809b2e2ba26',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\numYFYCLwmWwHbEWDT5QA\n=Xhuu\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 5884de4f731aae8a2872ad813a9b5b98c4b15484\nparent 7da2efd9d382333bfc3a3fde45db02e1a4ad9048\nauthor Eugene Yurtsev <eyurtsev@gmail.com> 1728487558 -0400\ncommitter GitHub <noreply@github.com> 1728487558 -0400\n\ncore[patch]: Ignore ASYNC110 to upgrade to newest ruff version (#27229)\n\nIgnoring ASYNC110 with explanation'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/5b9b8fe80f70af5a627630c1abc3b809b2e2ba26',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/5b9b8fe80f70af5a627630c1abc3b809b2e2ba26',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/5b9b8fe80f70af5a627630c1abc3b809b2e2ba26/comments',
#   'author': {'login': 'eyurtsev',
#    'id': 3205522,
#    'node_id': 'MDQ6VXNlcjMyMDU1MjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3205522?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eyurtsev',
#    'html_url': 'https://github.com/eyurtsev',
#    'followers_url': 'https://api.github.com/users/eyurtsev/followers',
#    'following_url': 'https://api.github.com/users/eyurtsev/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/eyurtsev/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/eyurtsev/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/eyurtsev/subscriptions',
#    'organizations_url': 'https://api.github.com/users/eyurtsev/orgs',
#    'repos_url': 'https://api.github.com/users/eyurtsev/repos',
#    'events_url': 'https://api.github.com/users/eyurtsev/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/eyurtsev/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '7da2efd9d382333bfc3a3fde45db02e1a4ad9048',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/7da2efd9d382333bfc3a3fde45db02e1a4ad9048',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/7da2efd9d382333bfc3a3fde45db02e1a4ad9048'}]},
#  {'sha': '7da2efd9d382333bfc3a3fde45db02e1a4ad9048',
#   'node_id': 'C_kwDOIPDwltoAKDdkYTJlZmQ5ZDM4MjMzM2JmYzNhM2ZkZTQ1ZGIwMmUxYTRhZDkwNDg',
#   'commit': {'author': {'name': 'Vittorio Rigamonti',
#     'email': 'rigazilla@users.noreply.github.com',
#     'date': '2024-10-09T14:51:39Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-10-09T14:51:39Z'},
#    'message': 'community[minor]: VectorStore Infinispan. Adding TLS and authentication (#23522)\n\n**Description**:\r\nthis PR enable VectorStore TLS and authentication (digest, basic) with\r\nHTTP/2 for Infinispan server.\r\nBased on httpx.\r\n\r\nAdded docker-compose facilities for testing\r\nAdded documentation\r\n\r\n**Dependencies:**\r\nrequires `pip install httpx[http2]` if HTTP2 is needed\r\n\r\n**Twitter handle:**\r\nhttps://twitter.com/infinispan',
#    'tree': {'sha': '002a61d57e90bcef63c4c483fdc9536970ee8f1c',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/002a61d57e90bcef63c4c483fdc9536970ee8f1c'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/7da2efd9d382333bfc3a3fde45db02e1a4ad9048',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nwqCJpA2X/PmIaT8ea0yv\n=58ht\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 002a61d57e90bcef63c4c483fdc9536970ee8f1c\nparent ff925d2ddc27a9b1f76fc281ae22a6df310581da\nauthor Vittorio Rigamonti <rigazilla@users.noreply.github.com> 1728485499 +0200\ncommitter GitHub <noreply@github.com> 1728485499 -0400\n\ncommunity[minor]: VectorStore Infinispan. Adding TLS and authentication (#23522)\n\n**Description**:\r\nthis PR enable VectorStore TLS and authentication (digest, basic) with\r\nHTTP/2 for Infinispan server.\r\nBased on httpx.\r\n\r\nAdded docker-compose facilities for testing\r\nAdded documentation\r\n\r\n**Dependencies:**\r\nrequires `pip install httpx[http2]` if HTTP2 is needed\r\n\r\n**Twitter handle:**\r\nhttps://twitter.com/infinispan'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/7da2efd9d382333bfc3a3fde45db02e1a4ad9048',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/7da2efd9d382333bfc3a3fde45db02e1a4ad9048',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/7da2efd9d382333bfc3a3fde45db02e1a4ad9048/comments',
#   'author': {'login': 'rigazilla',
#    'id': 7080882,
#    'node_id': 'MDQ6VXNlcjcwODA4ODI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7080882?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rigazilla',
#    'html_url': 'https://github.com/rigazilla',
#    'followers_url': 'https://api.github.com/users/rigazilla/followers',
#    'following_url': 'https://api.github.com/users/rigazilla/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rigazilla/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rigazilla/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rigazilla/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rigazilla/orgs',
#    'repos_url': 'https://api.github.com/users/rigazilla/repos',
#    'events_url': 'https://api.github.com/users/rigazilla/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rigazilla/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'ff925d2ddc27a9b1f76fc281ae22a6df310581da',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/ff925d2ddc27a9b1f76fc281ae22a6df310581da',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/ff925d2ddc27a9b1f76fc281ae22a6df310581da'}]},
#  {'sha': 'ff925d2ddc27a9b1f76fc281ae22a6df310581da',
#   'node_id': 'C_kwDOIPDwltoAKGZmOTI1ZDJkZGMyN2E5YjFmNzZmYzI4MWFlMjJhNmRmMzEwNTgxZGE',
#   'commit': {'author': {'name': 'Luke Jang',
#     'email': '125160399+wkdghdus@users.noreply.github.com',
#     'date': '2024-10-09T14:05:22Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-10-09T14:05:22Z'},
#    'message': 'docs: fixed broken API reference link for StructuredTool.from_function (#27181)\n\nFix broken API reference link for StructuredTool.from_function',
#    'tree': {'sha': '063cef523c4de51a47703769ba32ecd4be6c61d7',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/063cef523c4de51a47703769ba32ecd4be6c61d7'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/ff925d2ddc27a9b1f76fc281ae22a6df310581da',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nMD70xMPlAGhxQt8j/cbl\n=+53j\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 063cef523c4de51a47703769ba32ecd4be6c61d7\nparent 4553573acbe5bde3e10035ea9cb33a2eb0336d91\nauthor Luke Jang <125160399+wkdghdus@users.noreply.github.com> 1728482722 +0900\ncommitter GitHub <noreply@github.com> 1728482722 -0400\n\ndocs: fixed broken API reference link for StructuredTool.from_function (#27181)\n\nFix broken API reference link for StructuredTool.from_function'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/ff925d2ddc27a9b1f76fc281ae22a6df310581da',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/ff925d2ddc27a9b1f76fc281ae22a6df310581da',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/ff925d2ddc27a9b1f76fc281ae22a6df310581da/comments',
#   'author': {'login': 'wkdghdus',
#    'id': 125160399,
#    'node_id': 'U_kgDOB3XLzw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/125160399?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wkdghdus',
#    'html_url': 'https://github.com/wkdghdus',
#    'followers_url': 'https://api.github.com/users/wkdghdus/followers',
#    'following_url': 'https://api.github.com/users/wkdghdus/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/wkdghdus/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/wkdghdus/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/wkdghdus/subscriptions',
#    'organizations_url': 'https://api.github.com/users/wkdghdus/orgs',
#    'repos_url': 'https://api.github.com/users/wkdghdus/repos',
#    'events_url': 'https://api.github.com/users/wkdghdus/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/wkdghdus/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '4553573acbe5bde3e10035ea9cb33a2eb0336d91',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/4553573acbe5bde3e10035ea9cb33a2eb0336d91',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/4553573acbe5bde3e10035ea9cb33a2eb0336d91'}]},
#  {'sha': '4553573acbe5bde3e10035ea9cb33a2eb0336d91',
#   'node_id': 'C_kwDOIPDwltoAKDQ1NTM1NzNhY2JlNWJkZTNlMTAwMzVlYTljYjMzYTJlYjAzMzZkOTE',
#   'commit': {'author': {'name': 'Diao Zihao',
#     'email': 'diao.zihao@icloud.com',
#     'date': '2024-10-09T14:00:45Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-10-09T14:00:45Z'},
#    'message': 'core[patch],langchain[patch],community[patch]: Bump version dependency of tenacity to >=8.1.0,!=8.4.0,<10 (#27201)\n\nThis should fixes the compatibility issue with graprag as in\r\n\r\n- https://github.com/langchain-ai/langchain/discussions/25595\r\n\r\nHere are the release notes for tenacity 9\r\n(https://github.com/jd/tenacity/releases/tag/9.0.0)\r\n\r\n---------\r\n\r\nSigned-off-by: Zihao Diao <hi@ericdiao.com>\r\nCo-authored-by: Eugene Yurtsev <eugene@langchain.dev>\r\nCo-authored-by: Eugene Yurtsev <eyurtsev@gmail.com>',
#    'tree': {'sha': 'c08c8285550a4ff969cc22bf7b410732299b2807',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/c08c8285550a4ff969cc22bf7b410732299b2807'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/4553573acbe5bde3e10035ea9cb33a2eb0336d91',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nd7O/EK/uEi3gzSNbY/dB\n=tHZ7\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree c08c8285550a4ff969cc22bf7b410732299b2807\nparent d05fdd97ddf1a5302fd9980f1b48823a5c1540b9\nauthor Diao Zihao <diao.zihao@icloud.com> 1728482445 -0400\ncommitter GitHub <noreply@github.com> 1728482445 +0000\n\ncore[patch],langchain[patch],community[patch]: Bump version dependency of tenacity to >=8.1.0,!=8.4.0,<10 (#27201)\n\nThis should fixes the compatibility issue with graprag as in\r\n\r\n- https://github.com/langchain-ai/langchain/discussions/25595\r\n\r\nHere are the release notes for tenacity 9\r\n(https://github.com/jd/tenacity/releases/tag/9.0.0)\r\n\r\n---------\r\n\r\nSigned-off-by: Zihao Diao <hi@ericdiao.com>\r\nCo-authored-by: Eugene Yurtsev <eugene@langchain.dev>\r\nCo-authored-by: Eugene Yurtsev <eyurtsev@gmail.com>'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/4553573acbe5bde3e10035ea9cb33a2eb0336d91',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/4553573acbe5bde3e10035ea9cb33a2eb0336d91',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/4553573acbe5bde3e10035ea9cb33a2eb0336d91/comments',
#   'author': {'login': 'EricDiao',
#    'id': 8833243,
#    'node_id': 'MDQ6VXNlcjg4MzMyNDM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8833243?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/EricDiao',
#    'html_url': 'https://github.com/EricDiao',
#    'followers_url': 'https://api.github.com/users/EricDiao/followers',
#    'following_url': 'https://api.github.com/users/EricDiao/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/EricDiao/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/EricDiao/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/EricDiao/subscriptions',
#    'organizations_url': 'https://api.github.com/users/EricDiao/orgs',
#    'repos_url': 'https://api.github.com/users/EricDiao/repos',
#    'events_url': 'https://api.github.com/users/EricDiao/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/EricDiao/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'd05fdd97ddf1a5302fd9980f1b48823a5c1540b9',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/d05fdd97ddf1a5302fd9980f1b48823a5c1540b9',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/d05fdd97ddf1a5302fd9980f1b48823a5c1540b9'}]},
#  {'sha': 'd05fdd97ddf1a5302fd9980f1b48823a5c1540b9',
#   'node_id': 'C_kwDOIPDwltoAKGQwNWZkZDk3ZGRmMWE1MzAyZmQ5OTgwZjFiNDg4MjNhNWMxNTQwYjk',
#   'commit': {'author': {'name': 'Stefano Lottini',
#     'email': 'hemidactylus@users.noreply.github.com',
#     'date': '2024-10-09T06:41:34Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-10-09T06:41:34Z'},
#    'message': "community: Cassandra Vector Store: extend metadata-related methods (#27078)\n\n**Description:** this PR adds a set of methods to deal with metadata\r\nassociated to the vector store entries. These, while essential to the\r\nGraph-related extension of the `Cassandra` vector store, are also useful\r\nin themselves. These are (all come in their sync+async versions):\r\n\r\n- `[a]delete_by_metadata_filter`\r\n- `[a]replace_metadata`\r\n- `[a]get_by_document_id`\r\n- `[a]metadata_search`\r\n\r\nAdditionally, a `[a]similarity_search_with_embedding_id_by_vector`\r\nmethod is introduced to better serve the store's internal working (esp.\r\nrelated to reranking logic).\r\n\r\n**Issue:** no issue number, but now all Document's returned bear their\r\n`.id` consistently (as a consequence of a slight refactoring in how the\r\nraw entries read from DB are made back into `Document` instances).\r\n\r\n**Dependencies:** (no new deps: packaging comes through langchain-core\r\nalready; `cassio` is now required to be version 0.1.10+)\r\n\r\n\r\n**Add tests and docs**\r\nAdded integration tests for the relevant newly-introduced methods.\r\n(Docs will be updated in a separate PR).\r\n\r\n**Lint and test** Lint and (updated) test all pass.\r\n\r\n---------\r\n\r\nCo-authored-by: Erick Friis <erick@langchain.dev>",
#    'tree': {'sha': '218b836ea794438db3d8d05f864eefc062648cda',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/218b836ea794438db3d8d05f864eefc062648cda'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/d05fdd97ddf1a5302fd9980f1b48823a5c1540b9',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\ntiSCbOFwRQ3sblSEq9Zj\n=K0h/\n-----END PGP SIGNATURE-----\n',
#     'payload': "tree 218b836ea794438db3d8d05f864eefc062648cda\nparent 84c05b031de0480c6053145df05ae0d5bc0f753e\nauthor Stefano Lottini <hemidactylus@users.noreply.github.com> 1728456094 +0200\ncommitter GitHub <noreply@github.com> 1728456094 +0000\n\ncommunity: Cassandra Vector Store: extend metadata-related methods (#27078)\n\n**Description:** this PR adds a set of methods to deal with metadata\r\nassociated to the vector store entries. These, while essential to the\r\nGraph-related extension of the `Cassandra` vector store, are also useful\r\nin themselves. These are (all come in their sync+async versions):\r\n\r\n- `[a]delete_by_metadata_filter`\r\n- `[a]replace_metadata`\r\n- `[a]get_by_document_id`\r\n- `[a]metadata_search`\r\n\r\nAdditionally, a `[a]similarity_search_with_embedding_id_by_vector`\r\nmethod is introduced to better serve the store's internal working (esp.\r\nrelated to reranking logic).\r\n\r\n**Issue:** no issue number, but now all Document's returned bear their\r\n`.id` consistently (as a consequence of a slight refactoring in how the\r\nraw entries read from DB are made back into `Document` instances).\r\n\r\n**Dependencies:** (no new deps: packaging comes through langchain-core\r\nalready; `cassio` is now required to be version 0.1.10+)\r\n\r\n\r\n**Add tests and docs**\r\nAdded integration tests for the relevant newly-introduced methods.\r\n(Docs will be updated in a separate PR).\r\n\r\n**Lint and test** Lint and (updated) test all pass.\r\n\r\n---------\r\n\r\nCo-authored-by: Erick Friis <erick@langchain.dev>"}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/d05fdd97ddf1a5302fd9980f1b48823a5c1540b9',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/d05fdd97ddf1a5302fd9980f1b48823a5c1540b9',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/d05fdd97ddf1a5302fd9980f1b48823a5c1540b9/comments',
#   'author': {'login': 'hemidactylus',
#    'id': 14221764,
#    'node_id': 'MDQ6VXNlcjE0MjIxNzY0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14221764?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hemidactylus',
#    'html_url': 'https://github.com/hemidactylus',
#    'followers_url': 'https://api.github.com/users/hemidactylus/followers',
#    'following_url': 'https://api.github.com/users/hemidactylus/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/hemidactylus/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/hemidactylus/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/hemidactylus/subscriptions',
#    'organizations_url': 'https://api.github.com/users/hemidactylus/orgs',
#    'repos_url': 'https://api.github.com/users/hemidactylus/repos',
#    'events_url': 'https://api.github.com/users/hemidactylus/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/hemidactylus/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '84c05b031de0480c6053145df05ae0d5bc0f753e',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/84c05b031de0480c6053145df05ae0d5bc0f753e',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/84c05b031de0480c6053145df05ae0d5bc0f753e'}]},
#  {'sha': '84c05b031de0480c6053145df05ae0d5bc0f753e',
#   'node_id': 'C_kwDOIPDwltoAKDg0YzA1YjAzMWRlMDQ4MGM2MDUzMTQ1ZGYwNWFlMGQ1YmMwZjc1M2U',
#   'commit': {'author': {'name': 'Erick Friis',
#     'email': 'erick@langchain.dev',
#     'date': '2024-10-09T06:33:55Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-10-09T06:33:55Z'},
#    'message': 'community: release 0.3.2 (#27214)',
#    'tree': {'sha': '632504a01bfed2231914f5726f4246de7deac8a0',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/632504a01bfed2231914f5726f4246de7deac8a0'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/84c05b031de0480c6053145df05ae0d5bc0f753e',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n3aIOm1OP0ldcO3hPzpQW\n=FdCa\n-----END PGP SIGNATURE-----\n',
# ...
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': 'ea9a59bcf52eda76126a1f713f5eb4924494b215',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/ea9a59bcf52eda76126a1f713f5eb4924494b215',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/ea9a59bcf52eda76126a1f713f5eb4924494b215'}]},
#  {'sha': 'ea9a59bcf52eda76126a1f713f5eb4924494b215',
#   'node_id': 'C_kwDOIPDwltoAKGVhOWE1OWJjZjUyZWRhNzYxMjZhMWY3MTNmNWViNDkyNDQ5NGIyMTU',
#   'commit': {'author': {'name': 'Leonid Ganeline',
#     'email': 'leo.gan.57@gmail.com',
#     'date': '2024-10-08T17:03:18Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-10-08T17:03:18Z'},
#    'message': 'docs: `integrations` updates 17 (#27015)\n\nAdded missed provider pages. Added missed descriptions and links.\r\nI fixed the Ipex-LLM titles, so the ToC is now sorted properly for these\r\ntitles.\r\n\r\n---------\r\n\r\nCo-authored-by: Erick Friis <erick@langchain.dev>',
#    'tree': {'sha': '49d6c81972b6ccce996673eb3f756d38ff38a410',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/49d6c81972b6ccce996673eb3f756d38ff38a410'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/ea9a59bcf52eda76126a1f713f5eb4924494b215',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nChAZkoibHY9XaheSpF8B\n=rRjY\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 49d6c81972b6ccce996673eb3f756d38ff38a410\nparent 8d27325dbc987a79edd841d7e78759c9c9aad139\nauthor Leonid Ganeline <leo.gan.57@gmail.com> 1728406998 -0700\ncommitter GitHub <noreply@github.com> 1728406998 +0000\n\ndocs: `integrations` updates 17 (#27015)\n\nAdded missed provider pages. Added missed descriptions and links.\r\nI fixed the Ipex-LLM titles, so the ToC is now sorted properly for these\r\ntitles.\r\n\r\n---------\r\n\r\nCo-authored-by: Erick Friis <erick@langchain.dev>'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/ea9a59bcf52eda76126a1f713f5eb4924494b215',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/ea9a59bcf52eda76126a1f713f5eb4924494b215',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/ea9a59bcf52eda76126a1f713f5eb4924494b215/comments',
#   'author': {'login': 'leo-gan',
#    'id': 2256422,
#    'node_id': 'MDQ6VXNlcjIyNTY0MjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2256422?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/leo-gan',
#    'html_url': 'https://github.com/leo-gan',
#    'followers_url': 'https://api.github.com/users/leo-gan/followers',
#    'following_url': 'https://api.github.com/users/leo-gan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/leo-gan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/leo-gan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/leo-gan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/leo-gan/orgs',
#    'repos_url': 'https://api.github.com/users/leo-gan/repos',
#    'events_url': 'https://api.github.com/users/leo-gan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/leo-gan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '8d27325dbc987a79edd841d7e78759c9c9aad139',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/8d27325dbc987a79edd841d7e78759c9c9aad139',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/8d27325dbc987a79edd841d7e78759c9c9aad139'}]},
#  {'sha': '8d27325dbc987a79edd841d7e78759c9c9aad139',
#   'node_id': 'C_kwDOIPDwltoAKDhkMjczMjVkYmM5ODdhNzllZGQ4NDFkN2U3ODc1OWM5YzlhYWQxMzk',
#   'commit': {'author': {'name': 'Vadym Barda',
#     'email': 'vadym@langchain.dev',
#     'date': '2024-10-08T14:19:04Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-10-08T14:19:04Z'},
#    'message': 'core[patch]: support ValidationError from pydantic v1 in tools (#27194)',
#    'tree': {'sha': '6eb6a9116e25c9ba16fe4aff56068fcedcc1fe9b',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/6eb6a9116e25c9ba16fe4aff56068fcedcc1fe9b'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/8d27325dbc987a79edd841d7e78759c9c9aad139',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\nVMHKiLh4nD6KHWwQRHT+\n=KJ7j\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 6eb6a9116e25c9ba16fe4aff56068fcedcc1fe9b\nparent 16f5fdb38b307ee3f3b5065f671b28c90661b698\nauthor Vadym Barda <vadym@langchain.dev> 1728397144 -0400\ncommitter GitHub <noreply@github.com> 1728397144 -0400\n\ncore[patch]: support ValidationError from pydantic v1 in tools (#27194)\n\n'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/8d27325dbc987a79edd841d7e78759c9c9aad139',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/8d27325dbc987a79edd841d7e78759c9c9aad139',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/8d27325dbc987a79edd841d7e78759c9c9aad139/comments',
#   'author': {'login': 'vbarda',
#    'id': 19161700,
#    'node_id': 'MDQ6VXNlcjE5MTYxNzAw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19161700?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vbarda',
#    'html_url': 'https://github.com/vbarda',
#    'followers_url': 'https://api.github.com/users/vbarda/followers',
#    'following_url': 'https://api.github.com/users/vbarda/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/vbarda/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/vbarda/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/vbarda/subscriptions',
#    'organizations_url': 'https://api.github.com/users/vbarda/orgs',
#    'repos_url': 'https://api.github.com/users/vbarda/repos',
#    'events_url': 'https://api.github.com/users/vbarda/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/vbarda/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '16f5fdb38b307ee3f3b5065f671b28c90661b698',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/16f5fdb38b307ee3f3b5065f671b28c90661b698',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/16f5fdb38b307ee3f3b5065f671b28c90661b698'}]},
#  {'sha': '16f5fdb38b307ee3f3b5065f671b28c90661b698',
#   'node_id': 'C_kwDOIPDwltoAKDE2ZjVmZGIzOGIzMDdlZTNmM2I1MDY1ZjY3MWIyOGM5MDY2MWI2OTg',
#   'commit': {'author': {'name': 'Christophe Bornet',
#     'email': 'cbornet@hotmail.com',
#     'date': '2024-10-07T22:30:27Z'},
#    'committer': {'name': 'GitHub',
#     'email': 'noreply@github.com',
#     'date': '2024-10-07T22:30:27Z'},
#    'message': 'core: Add various ruff rules (#26836)\n\nAdds\r\n- ASYNC\r\n- COM\r\n- DJ\r\n- EXE\r\n- FLY\r\n- FURB\r\n- ICN\r\n- INT\r\n- LOG\r\n- NPY\r\n- PD\r\n- Q\r\n- RSE\r\n- SLOT\r\n- T10\r\n- TID\r\n- YTT\r\n\r\nCo-authored-by: Erick Friis <erick@langchain.dev>',
#    'tree': {'sha': '18800c4a2bb87a99de255b3a52e7ce37b1aaf037',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/git/trees/18800c4a2bb87a99de255b3a52e7ce37b1aaf037'},
#    'url': 'https://api.github.com/repos/langchain-ai/langchain/git/commits/16f5fdb38b307ee3f3b5065f671b28c90661b698',
#    'comment_count': 0,
#    'verification': {'verified': True,
#     'reason': 'valid',
#     'signature': '-----BEGIN PGP SIGNATURE-----\n\\n17Eg1VPbYLRcU4WvkLB5\n=Bn6N\n-----END PGP SIGNATURE-----\n',
#     'payload': 'tree 18800c4a2bb87a99de255b3a52e7ce37b1aaf037\nparent 5c826faece7aa5ade4d39e9fb09198dffc2b19c8\nauthor Christophe Bornet <cbornet@hotmail.com> 1728340227 +0200\ncommitter GitHub <noreply@github.com> 1728340227 +0000\n\ncore: Add various ruff rules (#26836)\n\nAdds\r\n- ASYNC\r\n- COM\r\n- DJ\r\n- EXE\r\n- FLY\r\n- FURB\r\n- ICN\r\n- INT\r\n- LOG\r\n- NPY\r\n- PD\r\n- Q\r\n- RSE\r\n- SLOT\r\n- T10\r\n- TID\r\n- YTT\r\n\r\nCo-authored-by: Erick Friis <erick@langchain.dev>'}},
#   'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/16f5fdb38b307ee3f3b5065f671b28c90661b698',
#   'html_url': 'https://github.com/langchain-ai/langchain/commit/16f5fdb38b307ee3f3b5065f671b28c90661b698',
#   'comments_url': 'https://api.github.com/repos/langchain-ai/langchain/commits/16f5fdb38b307ee3f3b5065f671b28c90661b698/comments',
#   'author': {'login': 'cbornet',
#    'id': 11633333,
#    'node_id': 'MDQ6VXNlcjExNjMzMzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11633333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cbornet',
#    'html_url': 'https://github.com/cbornet',
#    'followers_url': 'https://api.github.com/users/cbornet/followers',
#    'following_url': 'https://api.github.com/users/cbornet/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cbornet/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cbornet/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cbornet/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cbornet/orgs',
#    'repos_url': 'https://api.github.com/users/cbornet/repos',
#    'events_url': 'https://api.github.com/users/cbornet/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cbornet/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'committer': {'login': 'web-flow',
#    'id': 19864447,
#    'node_id': 'MDQ6VXNlcjE5ODY0NDQ3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/web-flow',
#    'html_url': 'https://github.com/web-flow',
#    'followers_url': 'https://api.github.com/users/web-flow/followers',
#    'following_url': 'https://api.github.com/users/web-flow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/web-flow/orgs',
#    'repos_url': 'https://api.github.com/users/web-flow/repos',
#    'events_url': 'https://api.github.com/users/web-flow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/web-flow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'parents': [{'sha': '5c826faece7aa5ade4d39e9fb09198dffc2b19c8',
#     'url': 'https://api.github.com/repos/langchain-ai/langchain/commits/5c826faece7aa5ade4d39e9fb09198dffc2b19c8',
#     'html_url': 'https://github.com/langchain-ai/langchain/commit/5c826faece7aa5ade4d39e9fb09198dffc2b19c8'}]}]

# %% [markdown]
# ## 解析导出每日进展
#
# API 请求返回结构过于复杂，我们先解析 `title` 字段，即仅查看和总结 GitHub 项目 Issues list 和 PRs List 标题。如下所示：
#
# ![Issues](images/issues.png)
#
# https://github.com/langchain-ai/langchain/issues

# %%
github_client.export_daily_progress(repo)
# Out:
# Exported daily progress to langchain-ai_langchain_2024-10-14.md
# 'langchain-ai_langchain_2024-10-14.md'

# %% [markdown]
# ### 查看文档 发现问题并不简单😈😈
#
# #### Note: Every pull request is an issue
#
# > GitHub's REST API considers every pull request an issue, but not every issue is a pull request. For this reason, "Issues" endpoints may return both issues and pull requests in the response. You can identify pull requests by the pull_request key. Be aware that the id of a pull request returned from "Issues" endpoints will be an issue id. To find out the pull request id, use the "List pull requests" endpoint.

# %% [markdown]
# # 支持条件筛选的 GitHub 项目进展获取
#
# 实际开发场景中，项目进展通常不是刚好以天为周期时。因此，这便暴露出v0.2版本的 `GitHubClient` 在信息获取方面的局限性。
#
#
# 下面我们扩展 v0.2 版本的 `GitHubClient`，使其支持根据筛选条件获取 GitHub 项目的 Issues 和 Pull Requests。首要支持的筛选条便是**研发周期（时间段）**，**已合并的PR** 和 **已关闭的Issues**：
#
# ![langchain_week_progress](images/langchain_week_progress.jpg)
#
# 通过阅读 GitHub API 文档（https://docs.github.com/en/rest/issues/issues?apiVersion=2022-11-28#list-repository-issues--code-samples ），我们便能了解最关键的2个字段是：
#
# - state(string): Indicates the state of the issues to return.
#     - Default: open
#     - Can be one of: open, closed, all
# - since(string): Only show results that were last updated after the given time. This is a timestamp in ISO 8601 format: YYYY-MM-DDTHH:MM:SSZ.
#
# 从功能完整性角度，我们还可以增加一个 `until` 条件，以支持研发周期的结束时间筛选。😈😈
#
#
# 下面以 Langchain 项目 (https://github.com/langchain-ai/langchain) 为例，展示如何使用扩展后的 GitHubClient
#
# ## [v0.3] GitHubClient Class

# %%
# src/logger.py
from loguru import logger
import sys
from datetime import datetime, date, timedelta

# Configure Loguru
logger.remove()  # Remove the default logger
logger.add(sys.stdout, level="DEBUG", format="{time} {level} {message}", colorize=True)
logger.add("logs/app.log", rotation="1 MB", level="DEBUG")

# Alias the logger for easier import
LOG = logger

# Make the logger available for import with the alias
__all__ = ["LOG"]


# src/github_client.py

import requests  # 导入requests库用于HTTP请求
from datetime import datetime, date, timedelta  # 导入日期处理模块
import os  # 导入os模块用于文件和目录操作
# from logger import LOG  # 导入日志模块（演示时直接导入）

class GitHubClient:
    def __init__(self, token):
        self.token = token  # GitHub API令牌
        self.headers = {'Authorization': f'token {self.token}'}  # 设置HTTP头部认证信息

    def fetch_updates(self, repo, since=None, until=None):
        # 获取指定仓库的更新，可以指定开始和结束日期
        updates = {
            'commits': self.fetch_commits(repo, since, until),  # 获取提交记录
            'issues': self.fetch_issues(repo, since, until),  # 获取问题
            'pull_requests': self.fetch_pull_requests(repo, since, until)  # 获取拉取请求
        }
        return updates

    def fetch_commits(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/commits'  # 构建获取提交的API URL
        params = {}
        if since:
            params['since'] = since  # 如果指定了开始日期，添加到参数中
        if until:
            params['until'] = until  # 如果指定了结束日期，添加到参数中

        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()  # 检查请求是否成功
        return response.json()  # 返回JSON格式的数据

    def fetch_issues(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/issues'  # 构建获取问题的API URL
        params = {
            'state': 'closed',  # 仅获取已关闭的问题
            'since': since,
            'until': until
        }
        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()
        return response.json()

    def fetch_pull_requests(self, repo, since=None, until=None):
        url = f'https://api.github.com/repos/{repo}/pulls'  # 构建获取拉取请求的API URL
        params = {
            'state': 'closed',  # 仅获取已合并的拉取请求
            'since': since,
            'until': until
        }
        response = requests.get(url, headers=self.headers, params=params)
        response.raise_for_status()
        return response.json()

    def export_daily_progress(self, repo):
        today = datetime.now().date().isoformat()  # 获取今天的日期
        updates = self.fetch_updates(repo, since=today)  # 获取今天的更新数据
        
        repo_dir = os.path.join('daily_progress', repo.replace("/", "_"))  # 构建存储路径
        os.makedirs(repo_dir, exist_ok=True)  # 确保目录存在
        
        file_path = os.path.join(repo_dir, f'{today}.md')  # 构建文件路径
        with open(file_path, 'w') as file:
            file.write(f"# Daily Progress for {repo} ({today})\n\n")
            file.write("\n## Issues Closed Today\n")
            for issue in updates['issues']:  # 写入今天关闭的问题
                file.write(f"- {issue['title']} #{issue['number']}\n")
            file.write("\n## Pull Requests Merged Today\n")
            for pr in updates['pull_requests']:  # 写入今天合并的拉取请求
                file.write(f"- {pr['title']} #{pr['number']}\n")
        
        LOG.info(f"Exported daily progress to {file_path}")  # 记录日志
        return file_path

    def export_progress_by_date_range(self, repo, days):
        today = date.today()  # 获取当前日期
        since = today - timedelta(days=days)  # 计算开始日期
        
        updates = self.fetch_updates(repo, since=since.isoformat(), until=today.isoformat())  # 获取指定日期范围内的更新
        
        repo_dir = os.path.join('daily_progress', repo.replace("/", "_"))  # 构建目录路径
        os.makedirs(repo_dir, exist_ok=True)  # 确保目录存在
        
        # 更新文件名以包含日期范围
        date_str = f"{since}_to_{today}"
        file_path = os.path.join(repo_dir, f'{date_str}.md')  # 构建文件路径
        
        with open(file_path, 'w') as file:
            file.write(f"# Progress for {repo} ({since} to {today})\n\n")
            file.write(f"\n## Issues Closed in the Last {days} Days\n")
            for issue in updates['issues']:  # 写入在指定日期内关闭的问题
                file.write(f"- {issue['title']} #{issue['number']}\n")
            file.write(f"\n## Pull Requests Merged in the Last {days} Days\n")
            for pr in updates['pull_requests']:  # 写入在指定日期内合并的拉取请求
                file.write(f"- {pr['title']} #{pr['number']}\n")
        
        LOG.info(f"Exported time-range progress to {file_path}")  # 记录日志
        return file_path

# %%
# 实例化 v0.3 版本的 GitHub Client
github_client = GitHubClient(token="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")

# %% [markdown]
# ### 获取过去1天 LangChain 进展（已关闭的Issues）

# %%
import datetime

# 获取今天的日期，从午夜开始，ISO 8601格式
today = datetime.datetime.now().replace(hour=0, minute=0, second=0, microsecond=0).isoformat()

# 获取今天关闭的Issues
closed_issues_today = github_client.fetch_issues(repo='langchain-ai/langchain', since=today, until=today)

# 打印今天关闭的Issues标题
for issue in closed_issues_today:
    print(f"Issue #{issue['number']}: {issue['title']} (关闭时间 {issue['closed_at']})")

# %%
# 获取过去3天的日期
three_days_ago = datetime.datetime.now() - datetime.timedelta(days=3)
three_days_ago = three_days_ago.replace(hour=0, minute=0, second=0, microsecond=0).isoformat()

# 获取过去3天关闭的Issues
closed_issues_last_3_days = github_client.fetch_issues(repo='langchain-ai/langchain', since=three_days_ago, until=today)

# 打印过去3天关闭的Issues标题
for issue in closed_issues_last_3_days:
    print(f"Issue #{issue['number']}: {issue['title']} (关闭时间 {issue['closed_at']})")
# Out:
# Issue #27320: community: Resolve Pydantic AttributeError in document_loaders/youtube.py  (关闭时间 2024-10-13T20:05:15Z)
# Issue #27308: RunnableWithMessageHistory ValueError: Attempting to use a sync method in when async mode is turned on. Please use the corresponding async method instead. (关闭时间 2024-10-12T22:54:20Z)
# Issue #27290: concepts docs: archictecture individual page (关闭时间 2024-10-11T20:06:57Z)
# Issue #27284: Unable to create custom callback for pandas agent during intermediate execution (关闭时间 2024-10-11T20:15:06Z)
# Issue #27277: scaffold (关闭时间 2024-10-11T19:50:37Z)
# Issue #27172: docs: add discussions with giscus (关闭时间 2024-10-11T22:14:45Z)
# Issue #27127: core: release 0.2.42 (关闭时间 2024-10-11T22:14:53Z)
# Issue #26487: Fix typo in conda environment code block in rag.ipynb (关闭时间 2024-09-17T22:13:55Z)
# Issue #26041: fix: Problem with embeddings in new versions of clickhouse. (关闭时间 2024-10-11T18:54:50Z)
# Issue #23953: No possibility to define WhisperModel compute_type when using GenericLoader with blob_parser=FasterWhisperParser (关闭时间 2024-10-13T16:04:49Z)
# Issue #23952: 'SelfQueryRetriever' object has no attribute 'add_documents' (关闭时间 2024-10-13T16:04:47Z)
# Issue #23949: DOC: <Issue related to /v0.2/docs/tutorials/local_rag/> Failed to create vectorstore using GPT4AllEmbedding() (关闭时间 2024-10-13T16:04:39Z)
# Issue #23936: Two conflicting declarations of AzureChatOpenAI (关闭时间 2024-10-12T16:08:05Z)
# Issue #23902: DOC: <Issue related to /v0.1/docs/modules/memory/chat_messages/> 404 on ChatMessageHistory link (关闭时间 2024-10-13T16:04:29Z)
# Issue #23901: when run method “with_structured_output”, output print nothing??  code was copied from langchain doc. (关闭时间 2024-10-12T16:07:50Z)
# Issue #23898: sample_rows_in_table_info: int = 3, I don't want to use top N rows, but select some rows manually to be passed to SQLDatabase (关闭时间 2024-10-11T16:04:22Z)
# Issue #23881: Agents and GraphQL- 401 Client Error: Unauthorized for url: https://streaming.bitquery.io/eap (关闭时间 2024-10-11T16:04:06Z)
# Issue #23861: DOC: remove_node typo in runnables/ graph (关闭时间 2024-10-11T16:03:56Z)
# Issue #23407: openai.APIError: The model produced invalid content. (关闭时间 2024-10-11T16:03:53Z)
# Issue #23250: SemanticChunker: list index out of range (关闭时间 2024-10-11T16:03:31Z)
# Issue #22674: ChatDatabricks can't stream response: "KeyError: 'content'" (关闭时间 2024-10-11T16:03:21Z)
# Issue #22385: GraphCypherQAChain cannot generate correct Cypher commands (关闭时间 2024-10-09T16:05:03Z)
# Issue #20479: Failed to batch ingest runs: LangSmithError('Failed to POST https://api.smith.langchain.com/runs/batch in LangSmith API. HTTPError(\'403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Forbidden"}\')') (关闭时间 2024-04-16T14:03:30Z)
# Issue #19629: vectorstore.similaritySearchWithScore in NodeJS not the same as vectorstore.similarity_search_with_relevance_scores in Python (关闭时间 2024-10-11T16:03:06Z)
# Issue #17665: [Elasticsearch VectorStore] Could not find trained model (关闭时间 2024-10-11T16:03:01Z)
# Issue #14185: Issue: Unable to properly parse output of custom chat agent.  (关闭时间 2024-07-02T16:08:06Z)
# Issue #12631: DOC: Import Error while creating SelfQueryRetriever (关闭时间 2024-02-08T16:11:30Z)
# Issue #9761: SelfQueryRetriever creates attributes that do not exist (关闭时间 2023-12-01T16:06:57Z)
# Issue #7190: Issue: Missing some input keys: {'question'} when using ConversationalRetrievalChain (关闭时间 2023-07-06T13:05:01Z)
# Issue #6162: Retrieval Question/Answering Example not working in 0.0.200 (关闭时间 2023-06-27T06:42:45Z)

# %% [markdown]
# ## 优化导出文件管理
#
# 考虑到 GitHubSentinel 项目长期运行将会生成一大批项目进展文件，因此将所有进展文件统一存储在`daily_progress` 目录下，并按照 `{owners}_{repo}/{since_day}_{until_day}.md` 方式命名。
#
# 如下所示：
#
# ```shell
# daily_progress
# ├── langchain-ai_langchain
# │   ├── 2024-08-04.md
# │   ├── 2024-08-04_report.md
# │   ├── 2024-08-18.md
# │   └── 2024-08-18_report.md
# ├── llm_logs.log
# ├── ollama_ollama
# │   ├── 2024-07-30_to_2024-08-04.md
# │   ├── 2024-07-30_to_2024-08-04_report.md
# │   ├── 2024-08-02_to_2024-08-04.md
# │   ├── 2024-08-02_to_2024-08-04_report.md
# │   ├── 2024-08-04.md
# │   └── 2024-08-04_report.md
# ```

# %%
github_client.export_progress_by_date_range(repo='langchain-ai/langchain', days=3)
# Out:
# 2024-10-14T16:34:20.333999+0800 INFO Exported time-range progress to daily_progress/langchain-ai_langchain/2024-10-11_to_2024-10-14.md
# 'daily_progress/langchain-ai_langchain/2024-10-11_to_2024-10-14.md'

# %%
github_client.export_daily_progress(repo='langchain-ai/langchain')
# Out:
# 2024-10-14T16:38:11.016605+0800 INFO Exported daily progress to daily_progress/langchain-ai_langchain/2024-10-14.md
# 'daily_progress/langchain-ai_langchain/2024-10-14.md'

# %% [markdown]
# ### Homework: 尝试扩展 GitHubClient，使其支持 Until 参数条件筛选
